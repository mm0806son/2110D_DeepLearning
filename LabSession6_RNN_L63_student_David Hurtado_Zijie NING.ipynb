# %% [markdown]
# # Lab session 6: Recurrent Neural Networks (RNN)
#
# Authors: [pierre.tandeo@imt-atlantique.fr](pierre.tandeo@imt-atlantique.fr), [lucas.drumetz@imt-atlantique.fr](lucas.drumetz@imt-atlantique.fr), [simon.benaichouche@imt-atlantique.fr](simon.benaichouche@imt-atlantique.fr), [aurelien.colin@imt-atlantique.fr](aurelien.colin@imt-atlantique.fr), [quentin.febvre@imt-atlantique.fr](quentin.febvre@imt-atlantique.fr)
#
# Year: 2021-2022

# %% [markdown]
# Student 1: David HURTADO
#
# Student 2: Zijie NING

# %% [markdown]
# In this practice, we will use a Recurrent Neural Networks (RNN) to fit multivariate time series and to make some predictions in the future. We will use the Lorenz-63 chaotic model, also known as the strange attractor (see https://en.wikipedia.org/wiki/Lorenz_system for more details).
#
# First, we will generate and visualize trajectories from the Lorenz-63 system. From these data, we will build training and test datasets. Then, we will adjust two models to fit the data: a classic linear autoregressive model and the specific LSTM (Long Short-Term Memory) architecture of RNN. Finally, we will compare these models in terms of prediction and simulation of new trajectories.

# %%
# Import libraries
# %pylab inline
# %matplotlib inline

# Import PyTorch
import torch
import torch.nn as nn
import torch.optim as optim

# Parameters (figure size)
pylab.rcParams['figure.figsize'] = (16, 9)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **A few words about the use of GPUs**
#
# In order to accelerate the optimization of your LSTM, we suggest to use GPUs. In Google Colab, you will need to enable GPUs for the notebook:
# * navigate to Edit → Notebook Settings
# * select GPU from the Hardware Accelerator drop-down
#
# Then, the use of GPU in PyTorch is based on four steps:
# * declare the GPU device (cell below)
# * transfer the training data to the GPU
# * use the GPU to learn the model
# * transfer the results to the CPU
#
# You will find more explanations here: https://towardsdatascience.com/pytorch-switching-to-the-gpu-a7c0b21e8a99.

# %%
# Declare the GPU (its name is "device")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('Using device '+str(device))
# Out:
# Using device cuda

# %% [markdown]
# **Generate data**
#
# Below, we define the 3-dimensional Lorenz-63 model given by:
#
# $\begin{aligned}{\frac {\mathrm {d} x_1}{\mathrm {d} t}}&=\sigma (x_2-x_1),\\[6pt]{\frac {\mathrm {d} x_2}{\mathrm {d} t}}&=x_1(\rho -x_3)-x_2,\\[6pt]{\frac {\mathrm {d} x_3}{\mathrm {d} t}}&=x_1 x_2-\beta x_3.\end{aligned}$
#
# This ordinary differential equation is using 3 physical parameters and we fix them to $\sigma=10$, $\rho=28$ and $\beta=8/3$. Then, we use Runge-Kutta 4-5 to integrate the model, using the *odeint()* Python function. The integration time is $0.01$ and we generate a sequence of $100$ Lorenz times.

# %%
# Lorenz-63 dynamical model
def Lorenz_63(x, dx, sigma, rho, beta):
    dx = zeros((3))
    dx[0] = sigma*(x[1]-x[0])
    dx[1] = x[0]*(rho-x[2])-x[1]
    dx[2] = x[0]*x[1] - beta*x[2]
    return dx

# %%
from scipy.integrate import odeint

# Define the parameters
x0 = array([8,0,30]) # initial condition
dt = 0.01 # integration time step
T = 100 # number of Lorenz-63 times
sigma = 10
rho = 28
beta = 8/3

# Generate the Lorenz-63 system
x = odeint(Lorenz_63, x0, arange(0.01,T,dt), args=(sigma,rho,beta))  
time = arange(0.01,T,dt)

# Transform array to tensor
x = torch.from_numpy(x).float()

# %% [markdown]
# **Visualize data**
#
# They are 2 ways of visualizing the Lorenz-63 system. The first is to consider the system as a 3-dimensional time series: we plot each variable as a function of time. The second is the phase-space representation where we plot the relationships between variables in 3D and we track the trajectory along time.

# %%
# Time series representation
plot(time, x)
xlabel('Lorenz-63 time', size=20)
legend(['x_1','x_2','x_3'], fontsize=20)

# %%
# Phase-space representation
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
ax.plot(x[:,0], x[:,1], x[:,2], 'k')
ax.set_xlabel('$x_1$', size=20)
ax.set_ylabel('$x_2$', size=20)
ax.set_zlabel('$x_3$', size=20)
# Out:
# Text(0.5, 0, '$x_3$')
# /usr/local/lib/python3.7/dist-packages/mpl_toolkits/mplot3d/proj3d.py:189: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array([xs, ys, zs, np.ones_like(xs)])

# %% [markdown]
# **Create the training and test datasets**
#
# Here, we want to predict the Lorenz-63 system at time t using the previous information at time t-0.01. It is thus a regression between the process and himself with a time delay. Here, we create a training (the first 2/3 of time series) and a test dataset (the last part).

# %%
# Size of the training set
T_train = int(T/dt*2/3)

# Training set
x_train = x[0:T_train,:]
y_train = x[1:T_train+1,:]

# Validation set
x_test = x[T_train+1:-1,]
y_test = x[T_train+2:,]

# %% [markdown]
# **Question 1:**
#
# For the 3 components of the Lorenz-63 system, plot *y_train* as a function of *x_train* and comment the relationship. What is happening if we increase the time delay (currently set to $0.01$) between *x_train* and *y_train*?

# %%
#############
### TODO ###
#############
import matplotlib.pyplot as plt
import numpy as np
plt.plot(x_train, y_train)
plt.legend(['component1', 'component2', 'component3', 'y_train'], prop={'size': 10})
plt.xlabel('x_train', size=10)
plt.ylabel('y_train', size=10)
# Out:
# Text(0, 0.5, 'y_train')

# %% [markdown]
# **Response:**
#
# xxx TO DO xxx
#
# Time delay is defiend by "dt".
#
# When increasing the time delay the curve becomes less smooth as it starts exhibiting a less linear behaviour. In contrast, when making smaller the dt, a more prominent linear behaviour is observed.
#
# When `dt=0.01`:
#
# ![](https://raw.githubusercontent.com/mm0806son/Images/main/202111121732148.jpeg)

# %% [markdown]
# **Question 2:**
#
# According to the previous question, propose a linear regression between *y_train* (at time t) and *x_train* (at time t-0.01). It corresponds to a multivariate order 1 autoregressive process noted AR(1), see more details here (https://en.wikipedia.org/wiki/Autoregressive_model).
#
# Implement the AR(1) regression using a neural network architecture (see lab session 1 & 2). Call your model *model_AR1*. Can you comment the estimated weights of the resulting neural network?

# %%
#############
### TODO ###
#############

class linear_regression_nn(nn.Module):
    
    # class initialization
    def __init__(self, input_size, output_size):
        super(linear_regression_nn, self).__init__()
        # fully connected layer with linear activation
        self.fc = nn.Linear(input_size, output_size)
        
    # function to apply the neural network
    def forward(self, x):
        y_pred = self.fc(x)
        return y_pred

# Create the neural network (3 input size for x and 3 output size for y, bias is declared by default)
model_AR1 = linear_regression_nn(3, 3)

# Print the model architecture
print(model_AR1)

# Print the model parameters (weights of the neural network)
slope, bias = model_AR1.parameters()
print('Slope: ', slope)
print('Bias: ', bias)
# Out:
# linear_regression_nn(
#   (fc): Linear(in_features=3, out_features=3, bias=True)
# )
# Slope:  Parameter containing:
# tensor([[-0.4499, -0.3739, -0.2487],
#         [ 0.0111, -0.3346, -0.2496],
#         [-0.0135, -0.1834, -0.1026]], requires_grad=True)
# Bias:  Parameter containing:
# tensor([-0.2353, -0.2921,  0.0270], requires_grad=True)

# %%
# Loss function: MSE = sum [(y - y_pred)^2], with y_pred = w0 + w1*x
criterion = nn.MSELoss()

# Optimizer: new_parameters = old_parameters - lr*gradient, with lr the learning rate
optimizer = torch.optim.SGD(model_AR1.parameters(), lr = 0.001)

# %%
epochs = 1000 # number of epochs
losses = [] # list to stock the loss at each iteration

# Loop on epochs
for i in range(epochs):
    
    # compute the prediction using the previous parameters of the neural network
    y_pred = model_AR1.forward(x_train)
    
    # compute and stock the loss
    loss = criterion(y_pred, y_train)
    losses.append(loss)
    
    # initialize the gradient to zero
    optimizer.zero_grad()
    
    # compute the gradient by back propagation
    loss.backward()
    
    # update the parameter values using the gradient
    optimizer.step()

# Print the model architecture
print(model_AR1)

# Print the model parameters (weights of the neural network)
slope, bias = model_AR1.parameters()
print('Slope: ', slope)
print('Bias: ', bias)
# Out:
# linear_regression_nn(
#   (fc): Linear(in_features=3, out_features=3, bias=True)
# )
# Slope:  Parameter containing:
# tensor([[ 0.8984,  0.1000,  0.0067],
#         [-0.1264,  1.0934,  0.0091],
#         [-0.0018,  0.0031,  0.9967]], requires_grad=True)
# Bias:  Parameter containing:
# tensor([-0.1774, -0.2153,  0.0750], requires_grad=True)

# %% [markdown]
# **Response:**
#
# xxx TO DO xxx
#
# After the training we can observe that the slope matrix looks more similar to the identity matrix, indicating a linear relationship between $x_t$ and $x_{t-1}$ for short time delays. However, there are still some non-linear components on the first and second columns where the values have a more significant discrepancy with respect to the identity matrix.

# %% [markdown]
# **Question 3:**
#
# Now, use a RNN architecture to learn the variations of the time series. To do so, we use the *LSTM()* function from PyTorch. Below, we provide you the dataset and a LSTM class. Here, we recommend that you use GPU acceleration.
#
# After implementing and fitting your RNN, have a look at the estimated parameters: what do they represent? See https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html for more details.

# %% [markdown]
# First, we have to rearange the dataset used to train the RNN. We also store the dataset on the GPU.

# %%
# Reshape train and test data (with batch_size = 1)
x_train_LSTM = reshape(x_train, (shape(x_train)[0], 1, shape(x_train)[1]))
x_test_LSTM = reshape(x_test, (shape(x_test)[0], 1, shape(x_test)[1]))
y_train_LSTM = reshape(y_train, (shape(y_train)[0], 1, shape(y_train)[1]))
y_test_LSTM = reshape(y_test, (shape(y_test)[0], 1, shape(y_test)[1]))

# Store the data on the GPU
x_train_LSTM, x_test_LSTM = x_train_LSTM.to(device), x_test_LSTM.to(device)
y_train_LSTM, y_test_LSTM = y_train_LSTM.to(device), y_test_LSTM.to(device)

# %% [markdown]
# Then, we suggest to use the following RNN architecture with one LSTM layer and a fully connected layer with linear activation.

# %%
# Declare a class for LSTM
class LSTM_nn(nn.Module):
    
    # class initialization
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTM_nn, self).__init__()
        # LSTM layer with 1 hidden layer (hidden_size neurons inside)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers = 1)
        # fully connected layer with linear activation
        self.fc = nn.Linear(hidden_size, output_size)

    # function to apply the neural network
    def forward(self, x):
        out, (h_out, c_out) = self.lstm(x)
        y_pred = self.fc(out)
        return y_pred, h_out, c_out

    # function to apply the neural network (when knowing the hidden state)
    def forward_using_last_hidden_layer(self, x, h, c):
        out, (h_out, c_out) = self.lstm(x, (h, c))
        y_pred = self.fc(out)
        return y_pred, h_out, c_out

# %% [markdown]
# In the next cell, we initialize a LSTM with 10 neurons in the hidden layer. Here, we transfer the LSTM model to the GPU.

# %%
# Create the LSTM (3 input size for x and 3 output size for y, 10 neurons in the hidden layer)
model_RNN = LSTM_nn(3, 10, 3)

# Use the GPU to train the model
model_RNN.to(device)
print(str(device))
# Out:
# cuda

# %% [markdown]
# Then, you will have to optimize the LSTM. We suggest to carrefully check the loss function along the epochs. The number of epoch needed to converge can be large, depending on the optimizer and the learning rate.

# %%
criterion = nn.CrossEntropyLoss() # specify loss function (categorical cross-entropy)
optimizer = torch.optim.SGD(model_RNN.parameters(),lr = 0.01) # specify optimizer (stochastic gradient descent) and learning rate

# %%
#############
### TO DO ###
#############
n_epochs = 2000 # number of epochs to train the model

losses = [] # list to stock the loss at each iteration

# Loss function: MSE = sum [(y - y_pred)^2], with y_pred = w0 + w1*x
criterion = nn.MSELoss()

# Optimizer: new_parameters = old_parameters - lr*gradient, with lr the learning rate
optimizer = torch.optim.SGD(model_RNN.parameters(), lr = 0.002)

for epoch in range(n_epochs):
    
    # compute the prediction using the previous parameters of the neural network
    
    y_pred,h_out,c_out = model_RNN.forward(x_train_LSTM)
    
    # compute and stock the loss
    loss = criterion(y_pred, y_train_LSTM)
    losses.append(loss)

    print('epoch: {} \ttraining Loss: {:.6f} '.format(epoch+1, loss))
    
    # initialize the gradient to zero
    optimizer.zero_grad()
    
    # compute the gradient by back propagation
    
    loss.backward(retain_graph=True)
    
    # update the parameter values using the gradient
    optimizer.step()
# Out:
# epoch: 1 	training Loss: 249.617767
# epoch: 2 	training Loss: 247.412201
# epoch: 3 	training Loss: 245.669296
# epoch: 4 	training Loss: 244.057632
# epoch: 5 	training Loss: 242.473892
# epoch: 6 	training Loss: 240.884689
# epoch: 7 	training Loss: 239.248978
# epoch: 8 	training Loss: 237.336029
# epoch: 9 	training Loss: 234.377594
# epoch: 10 	training Loss: 232.404785
# epoch: 11 	training Loss: 230.476776
# epoch: 12 	training Loss: 228.571915
# epoch: 13 	training Loss: 226.687790
# epoch: 14 	training Loss: 224.824234
# epoch: 15 	training Loss: 222.980804
# epoch: 16 	training Loss: 221.156998
# epoch: 17 	training Loss: 219.352432
# epoch: 18 	training Loss: 217.566910
# epoch: 19 	training Loss: 215.800430
# epoch: 20 	training Loss: 214.052780
# epoch: 21 	training Loss: 212.323135
# epoch: 22 	training Loss: 210.609970
# epoch: 23 	training Loss: 208.910690
# epoch: 24 	training Loss: 207.221954
# epoch: 25 	training Loss: 205.539658
# epoch: 26 	training Loss: 203.858932
# epoch: 27 	training Loss: 202.174393
# epoch: 28 	training Loss: 200.481079
# epoch: 29 	training Loss: 198.776352
# epoch: 30 	training Loss: 197.059525
# epoch: 31 	training Loss: 195.330688
# epoch: 32 	training Loss: 193.591904
# epoch: 33 	training Loss: 191.847931
# epoch: 34 	training Loss: 190.104446
# epoch: 35 	training Loss: 188.366623
# epoch: 36 	training Loss: 186.638412
# epoch: 37 	training Loss: 184.922516
# epoch: 38 	training Loss: 183.220764
# epoch: 39 	training Loss: 181.534348
# epoch: 40 	training Loss: 179.864166
# epoch: 41 	training Loss: 178.210846
# epoch: 42 	training Loss: 176.575180
# epoch: 43 	training Loss: 174.958084
# epoch: 44 	training Loss: 173.360413
# epoch: 45 	training Loss: 171.783051
# epoch: 46 	training Loss: 170.227020
# epoch: 47 	training Loss: 168.692963
# epoch: 48 	training Loss: 167.180740
# epoch: 49 	training Loss: 165.690048
# epoch: 50 	training Loss: 164.220596
# epoch: 51 	training Loss: 162.772293
# epoch: 52 	training Loss: 161.344955
# epoch: 53 	training Loss: 159.938492
# epoch: 54 	training Loss: 158.552734
# epoch: 55 	training Loss: 157.187454
# epoch: 56 	training Loss: 155.842438
# epoch: 57 	training Loss: 154.517426
# epoch: 58 	training Loss: 153.212143
# epoch: 59 	training Loss: 151.926270
# epoch: 60 	training Loss: 150.659470
# epoch: 61 	training Loss: 149.411423
# epoch: 62 	training Loss: 148.181747
# epoch: 63 	training Loss: 146.970093
# epoch: 64 	training Loss: 145.776031
# epoch: 65 	training Loss: 144.599228
# epoch: 66 	training Loss: 143.439224
# epoch: 67 	training Loss: 142.295609
# epoch: 68 	training Loss: 141.167969
# epoch: 69 	training Loss: 140.055878
# epoch: 70 	training Loss: 138.958862
# epoch: 71 	training Loss: 137.876495
# epoch: 72 	training Loss: 136.808350
# epoch: 73 	training Loss: 135.754013
# epoch: 74 	training Loss: 134.713150
# epoch: 75 	training Loss: 133.685425
# epoch: 76 	training Loss: 132.670715
# epoch: 77 	training Loss: 131.668900
# epoch: 78 	training Loss: 130.680099
# epoch: 79 	training Loss: 129.704437
# epoch: 80 	training Loss: 128.742111
# epoch: 81 	training Loss: 127.793259
# epoch: 82 	training Loss: 126.857941
# epoch: 83 	training Loss: 125.936081
# epoch: 84 	training Loss: 125.027542
# epoch: 85 	training Loss: 124.132050
# epoch: 86 	training Loss: 123.249275
# epoch: 87 	training Loss: 122.378815
# epoch: 88 	training Loss: 121.520256
# epoch: 89 	training Loss: 120.673065
# epoch: 90 	training Loss: 119.836708
# epoch: 91 	training Loss: 119.010468
# epoch: 92 	training Loss: 118.193520
# epoch: 93 	training Loss: 117.384918
# epoch: 94 	training Loss: 116.583481
# epoch: 95 	training Loss: 115.788033
# epoch: 96 	training Loss: 114.997467
# epoch: 97 	training Loss: 114.211220
# epoch: 98 	training Loss: 113.429855
# epoch: 99 	training Loss: 112.655220
# epoch: 100 	training Loss: 111.890244
# epoch: 101 	training Loss: 111.137817
# epoch: 102 	training Loss: 110.399826
# epoch: 103 	training Loss: 109.676758
# epoch: 104 	training Loss: 108.968147
# epoch: 105 	training Loss: 108.273041
# epoch: 106 	training Loss: 107.590462
# epoch: 107 	training Loss: 106.919556
# epoch: 108 	training Loss: 106.259636
# epoch: 109 	training Loss: 105.610184
# epoch: 110 	training Loss: 104.970772
# epoch: 111 	training Loss: 104.341019
# epoch: 112 	training Loss: 103.720612
# epoch: 113 	training Loss: 103.109230
# epoch: 114 	training Loss: 102.506561
# epoch: 115 	training Loss: 101.912270
# epoch: 116 	training Loss: 101.326035
# epoch: 117 	training Loss: 100.747490
# epoch: 118 	training Loss: 100.176346
# epoch: 119 	training Loss: 99.612312
# epoch: 120 	training Loss: 99.055244
# epoch: 121 	training Loss: 98.505142
# epoch: 122 	training Loss: 97.962173
# epoch: 123 	training Loss: 97.426620
# epoch: 124 	training Loss: 96.898712
# epoch: 125 	training Loss: 96.378494
# epoch: 126 	training Loss: 95.865761
# epoch: 127 	training Loss: 95.360176
# epoch: 128 	training Loss: 94.861397
# epoch: 129 	training Loss: 94.369186
# epoch: 130 	training Loss: 93.883385
# epoch: 131 	training Loss: 93.403931
# epoch: 132 	training Loss: 92.930832
# epoch: 133 	training Loss: 92.464172
# epoch: 134 	training Loss: 92.003975
# epoch: 135 	training Loss: 91.550240
# epoch: 136 	training Loss: 91.102943
# epoch: 137 	training Loss: 90.662018
# epoch: 138 	training Loss: 90.227394
# epoch: 139 	training Loss: 89.798996
# epoch: 140 	training Loss: 89.376762
# epoch: 141 	training Loss: 88.960594
# epoch: 142 	training Loss: 88.550415
# epoch: 143 	training Loss: 88.146049
# epoch: 144 	training Loss: 87.747398
# epoch: 145 	training Loss: 87.354263
# epoch: 146 	training Loss: 86.966446
# epoch: 147 	training Loss: 86.583794
# epoch: 148 	training Loss: 86.206123
# epoch: 149 	training Loss: 85.833267
# epoch: 150 	training Loss: 85.465065
# epoch: 151 	training Loss: 85.101379
# epoch: 152 	training Loss: 84.742065
# epoch: 153 	training Loss: 84.387024
# epoch: 154 	training Loss: 84.036140
# epoch: 155 	training Loss: 83.689293
# epoch: 156 	training Loss: 83.346413
# epoch: 157 	training Loss: 83.007385
# epoch: 158 	training Loss: 82.672150
# epoch: 159 	training Loss: 82.340607
# epoch: 160 	training Loss: 82.012680
# epoch: 161 	training Loss: 81.688286
# epoch: 162 	training Loss: 81.367363
# epoch: 163 	training Loss: 81.049820
# epoch: 164 	training Loss: 80.735573
# epoch: 165 	training Loss: 80.424553
# epoch: 166 	training Loss: 80.116692
# epoch: 167 	training Loss: 79.811882
# epoch: 168 	training Loss: 79.510056
# epoch: 169 	training Loss: 79.211136
# epoch: 170 	training Loss: 78.915016
# epoch: 171 	training Loss: 78.621635
# epoch: 172 	training Loss: 78.330887
# epoch: 173 	training Loss: 78.042694
# epoch: 174 	training Loss: 77.756935
# epoch: 175 	training Loss: 77.473564
# epoch: 176 	training Loss: 77.192436
# epoch: 177 	training Loss: 76.913460
# epoch: 178 	training Loss: 76.636543
# epoch: 179 	training Loss: 76.361565
# epoch: 180 	training Loss: 76.088387
# epoch: 181 	training Loss: 75.816872
# epoch: 182 	training Loss: 75.546883
# epoch: 183 	training Loss: 75.278206
# epoch: 184 	training Loss: 75.010651
# epoch: 185 	training Loss: 74.743965
# epoch: 186 	training Loss: 74.477837
# epoch: 187 	training Loss: 74.211868
# epoch: 188 	training Loss: 73.945633
# epoch: 189 	training Loss: 73.678429
# epoch: 190 	training Loss: 73.409355
# epoch: 191 	training Loss: 73.136810
# epoch: 192 	training Loss: 72.858177
# epoch: 193 	training Loss: 72.568817
# epoch: 194 	training Loss: 72.260414
# epoch: 195 	training Loss: 71.918266
# epoch: 196 	training Loss: 71.519012
# epoch: 197 	training Loss: 71.037506
# epoch: 198 	training Loss: 70.507423
# epoch: 199 	training Loss: 70.045532
# epoch: 200 	training Loss: 69.677597
# epoch: 201 	training Loss: 69.360077
# epoch: 202 	training Loss: 69.066452
# epoch: 203 	training Loss: 68.785255
# epoch: 204 	training Loss: 68.511398
# epoch: 205 	training Loss: 68.242447
# epoch: 206 	training Loss: 67.977158
# epoch: 207 	training Loss: 67.714859
# epoch: 208 	training Loss: 67.455162
# epoch: 209 	training Loss: 67.197845
# epoch: 210 	training Loss: 66.942711
# epoch: 211 	training Loss: 66.689529
# epoch: 212 	training Loss: 66.438057
# epoch: 213 	training Loss: 66.187973
# epoch: 214 	training Loss: 65.938911
# epoch: 215 	training Loss: 65.690491
# epoch: 216 	training Loss: 65.442322
# epoch: 217 	training Loss: 65.194061
# epoch: 218 	training Loss: 64.945396
# epoch: 219 	training Loss: 64.696121
# epoch: 220 	training Loss: 64.446083
# epoch: 221 	training Loss: 64.195236
# epoch: 222 	training Loss: 63.943619
# epoch: 223 	training Loss: 63.691296
# epoch: 224 	training Loss: 63.438293
# epoch: 225 	training Loss: 63.184589
# epoch: 226 	training Loss: 62.929981
# epoch: 227 	training Loss: 62.674229
# epoch: 228 	training Loss: 62.417706
# epoch: 229 	training Loss: 62.166042
# epoch: 230 	training Loss: 61.961910
# epoch: 231 	training Loss: 61.905972
# epoch: 232 	training Loss: 62.357838
# epoch: 233 	training Loss: 61.144402
# epoch: 234 	training Loss: 60.809013
# epoch: 235 	training Loss: 60.703308
# epoch: 236 	training Loss: 59.665085
# epoch: 237 	training Loss: 59.285347
# epoch: 238 	training Loss: 59.015427
# epoch: 239 	training Loss: 59.010788
# epoch: 240 	training Loss: 58.396404
# epoch: 241 	training Loss: 58.307705
# epoch: 242 	training Loss: 57.936707
# epoch: 243 	training Loss: 58.001362
# epoch: 244 	training Loss: 57.308830
# epoch: 245 	training Loss: 57.133312
# epoch: 246 	training Loss: 56.932938
# epoch: 247 	training Loss: 57.027416
# epoch: 248 	training Loss: 56.324390
# epoch: 249 	training Loss: 56.163578
# epoch: 250 	training Loss: 55.979034
# epoch: 251 	training Loss: 56.100254
# epoch: 252 	training Loss: 55.378014
# epoch: 253 	training Loss: 55.228600
# epoch: 254 	training Loss: 55.058105
# epoch: 255 	training Loss: 55.203300
# epoch: 256 	training Loss: 54.461552
# epoch: 257 	training Loss: 54.322495
# epoch: 258 	training Loss: 54.164429
# epoch: 259 	training Loss: 54.330334
# epoch: 260 	training Loss: 53.573009
# epoch: 261 	training Loss: 53.445969
# epoch: 262 	training Loss: 53.296982
# epoch: 263 	training Loss: 53.481724
# epoch: 264 	training Loss: 52.709808
# epoch: 265 	training Loss: 52.594055
# epoch: 266 	training Loss: 52.452435
# epoch: 267 	training Loss: 52.652908
# epoch: 268 	training Loss: 51.871719
# epoch: 269 	training Loss: 51.770367
# epoch: 270 	training Loss: 51.630989
# epoch: 271 	training Loss: 51.845558
# epoch: 272 	training Loss: 51.055836
# epoch: 273 	training Loss: 50.967903
# epoch: 274 	training Loss: 50.828571
# epoch: 275 	training Loss: 51.053791
# epoch: 276 	training Loss: 50.262333
# epoch: 277 	training Loss: 50.191658
# epoch: 278 	training Loss: 50.045124
# epoch: 279 	training Loss: 50.278530
# epoch: 280 	training Loss: 49.488655
# epoch: 281 	training Loss: 49.435291
# epoch: 282 	training Loss: 49.277317
# epoch: 283 	training Loss: 49.514988
# epoch: 284 	training Loss: 48.734974
# epoch: 285 	training Loss: 48.702194
# epoch: 286 	training Loss: 48.524483
# epoch: 287 	training Loss: 48.762115
# epoch: 288 	training Loss: 48.000210
# epoch: 289 	training Loss: 47.989635
# epoch: 290 	training Loss: 47.785511
# epoch: 291 	training Loss: 48.017761
# epoch: 292 	training Loss: 47.284081
# epoch: 293 	training Loss: 47.296997
# epoch: 294 	training Loss: 47.060123
# epoch: 295 	training Loss: 47.280933
# epoch: 296 	training Loss: 46.586411
# epoch: 297 	training Loss: 46.622986
# epoch: 298 	training Loss: 46.348171
# epoch: 299 	training Loss: 46.550850
# epoch: 300 	training Loss: 45.907181
# epoch: 301 	training Loss: 45.965908
# epoch: 302 	training Loss: 45.651245
# epoch: 303 	training Loss: 45.830673
# epoch: 304 	training Loss: 45.247425
# epoch: 305 	training Loss: 45.326115
# epoch: 306 	training Loss: 44.972591
# epoch: 307 	training Loss: 45.127800
# epoch: 308 	training Loss: 44.605736
# epoch: 309 	training Loss: 44.700081
# epoch: 310 	training Loss: 44.316605
# epoch: 311 	training Loss: 44.453346
# epoch: 312 	training Loss: 43.981213
# epoch: 313 	training Loss: 44.087967
# epoch: 314 	training Loss: 43.685081
# epoch: 315 	training Loss: 43.812126
# epoch: 316 	training Loss: 43.372112
# epoch: 317 	training Loss: 43.488293
# epoch: 318 	training Loss: 43.077381
# epoch: 319 	training Loss: 43.203571
# epoch: 320 	training Loss: 42.779366
# epoch: 321 	training Loss: 42.903965
# epoch: 322 	training Loss: 42.490387
# epoch: 323 	training Loss: 42.621113
# epoch: 324 	training Loss: 42.203133
# epoch: 325 	training Loss: 42.336178
# epoch: 326 	training Loss: 41.921375
# epoch: 327 	training Loss: 42.059364
# epoch: 328 	training Loss: 41.642853
# epoch: 329 	training Loss: 41.784756
# epoch: 330 	training Loss: 41.368538
# epoch: 331 	training Loss: 41.515221
# epoch: 332 	training Loss: 41.097767
# epoch: 333 	training Loss: 41.249073
# epoch: 334 	training Loss: 40.830708
# epoch: 335 	training Loss: 40.986973
# epoch: 336 	training Loss: 40.567158
# epoch: 337 	training Loss: 40.728481
# epoch: 338 	training Loss: 40.307106
# epoch: 339 	training Loss: 40.473698
# epoch: 340 	training Loss: 40.050472
# epoch: 341 	training Loss: 40.222515
# epoch: 342 	training Loss: 39.797237
# epoch: 343 	training Loss: 39.974941
# epoch: 344 	training Loss: 39.547367
# epoch: 345 	training Loss: 39.730930
# epoch: 346 	training Loss: 39.300854
# epoch: 347 	training Loss: 39.490456
# epoch: 348 	training Loss: 39.057690
# epoch: 349 	training Loss: 39.253506
# epoch: 350 	training Loss: 38.817886
# epoch: 351 	training Loss: 39.020023
# epoch: 352 	training Loss: 38.581413
# epoch: 353 	training Loss: 38.789944
# epoch: 354 	training Loss: 38.348228
# epoch: 355 	training Loss: 38.563133
# epoch: 356 	training Loss: 38.118244
# epoch: 357 	training Loss: 38.339478
# epoch: 358 	training Loss: 37.891335
# epoch: 359 	training Loss: 38.118851
# epoch: 360 	training Loss: 37.667393
# epoch: 361 	training Loss: 37.901176
# epoch: 362 	training Loss: 37.446281
# epoch: 363 	training Loss: 37.686394
# epoch: 364 	training Loss: 37.227875
# epoch: 365 	training Loss: 37.474461
# epoch: 366 	training Loss: 37.012051
# epoch: 367 	training Loss: 37.265366
# epoch: 368 	training Loss: 36.798698
# epoch: 369 	training Loss: 37.059120
# epoch: 370 	training Loss: 36.587723
# epoch: 371 	training Loss: 36.855827
# epoch: 372 	training Loss: 36.379040
# epoch: 373 	training Loss: 36.655586
# epoch: 374 	training Loss: 36.172554
# epoch: 375 	training Loss: 36.458504
# epoch: 376 	training Loss: 35.968102
# epoch: 377 	training Loss: 36.264759
# epoch: 378 	training Loss: 35.765575
# epoch: 379 	training Loss: 36.074757
# epoch: 380 	training Loss: 35.565269
# epoch: 381 	training Loss: 35.888691
# epoch: 382 	training Loss: 35.368591
# epoch: 383 	training Loss: 35.705414
# epoch: 384 	training Loss: 35.176407
# epoch: 385 	training Loss: 35.521889
# epoch: 386 	training Loss: 34.984173
# epoch: 387 	training Loss: 35.336826
# epoch: 388 	training Loss: 34.793308
# epoch: 389 	training Loss: 35.153519
# epoch: 390 	training Loss: 34.603577
# epoch: 391 	training Loss: 34.970993
# epoch: 392 	training Loss: 34.412689
# epoch: 393 	training Loss: 34.789078
# epoch: 394 	training Loss: 34.221153
# epoch: 395 	training Loss: 34.607143
# epoch: 396 	training Loss: 34.027241
# epoch: 397 	training Loss: 34.422531
# epoch: 398 	training Loss: 33.831707
# epoch: 399 	training Loss: 34.236263
# epoch: 400 	training Loss: 33.636658
# epoch: 401 	training Loss: 34.051403
# epoch: 402 	training Loss: 33.444012
# epoch: 403 	training Loss: 33.869465
# epoch: 404 	training Loss: 33.253651
# epoch: 405 	training Loss: 33.689224
# epoch: 406 	training Loss: 33.063564
# epoch: 407 	training Loss: 33.508900
# epoch: 408 	training Loss: 32.871346
# epoch: 409 	training Loss: 33.327782
# epoch: 410 	training Loss: 32.675812
# epoch: 411 	training Loss: 33.147163
# epoch: 412 	training Loss: 32.481537
# epoch: 413 	training Loss: 32.970913
# epoch: 414 	training Loss: 32.294918
# epoch: 415 	training Loss: 32.802380
# epoch: 416 	training Loss: 32.116753
# epoch: 417 	training Loss: 32.642109
# epoch: 418 	training Loss: 31.947269
# epoch: 419 	training Loss: 32.489540
# epoch: 420 	training Loss: 31.784733
# epoch: 421 	training Loss: 32.341572
# epoch: 422 	training Loss: 31.626907
# epoch: 423 	training Loss: 32.195869
# epoch: 424 	training Loss: 31.472582
# epoch: 425 	training Loss: 32.051651
# epoch: 426 	training Loss: 31.320971
# epoch: 427 	training Loss: 31.908426
# epoch: 428 	training Loss: 31.170105
# epoch: 429 	training Loss: 31.764589
# epoch: 430 	training Loss: 31.015514
# epoch: 431 	training Loss: 31.616619
# epoch: 432 	training Loss: 30.853760
# epoch: 433 	training Loss: 31.463253
# epoch: 434 	training Loss: 30.687393
# epoch: 435 	training Loss: 31.308149
# epoch: 436 	training Loss: 30.521915
# epoch: 437 	training Loss: 31.155912
# epoch: 438 	training Loss: 30.360449
# epoch: 439 	training Loss: 31.007364
# epoch: 440 	training Loss: 30.202539
# epoch: 441 	training Loss: 30.860504
# epoch: 442 	training Loss: 30.044292
# epoch: 443 	training Loss: 30.711943
# epoch: 444 	training Loss: 29.883392
# epoch: 445 	training Loss: 30.561134
# epoch: 446 	training Loss: 29.719097
# epoch: 447 	training Loss: 30.406559
# epoch: 448 	training Loss: 29.550549
# epoch: 449 	training Loss: 30.248095
# epoch: 450 	training Loss: 29.376507
# epoch: 451 	training Loss: 30.085709
# epoch: 452 	training Loss: 29.201105
# epoch: 453 	training Loss: 29.926723
# epoch: 454 	training Loss: 29.029320
# epoch: 455 	training Loss: 29.774193
# epoch: 456 	training Loss: 28.865265
# epoch: 457 	training Loss: 29.639565
# epoch: 458 	training Loss: 28.710596
# epoch: 459 	training Loss: 29.511202
# epoch: 460 	training Loss: 28.558250
# epoch: 461 	training Loss: 29.373981
# epoch: 462 	training Loss: 28.387011
# epoch: 463 	training Loss: 29.211018
# epoch: 464 	training Loss: 28.221886
# epoch: 465 	training Loss: 29.071320
# epoch: 466 	training Loss: 28.075033
# epoch: 467 	training Loss: 28.928699
# epoch: 468 	training Loss: 27.941292
# epoch: 469 	training Loss: 28.811150
# epoch: 470 	training Loss: 27.784485
# epoch: 471 	training Loss: 28.651875
# epoch: 472 	training Loss: 27.656206
# epoch: 473 	training Loss: 28.567390
# epoch: 474 	training Loss: 27.501957
# epoch: 475 	training Loss: 28.376707
# epoch: 476 	training Loss: 27.409298
# epoch: 477 	training Loss: 28.362427
# epoch: 478 	training Loss: 27.211721
# epoch: 479 	training Loss: 28.060600
# epoch: 480 	training Loss: 27.184338
# epoch: 481 	training Loss: 28.234814
# epoch: 482 	training Loss: 26.908682
# epoch: 483 	training Loss: 27.653490
# epoch: 484 	training Loss: 27.043812
# epoch: 485 	training Loss: 28.265034
# epoch: 486 	training Loss: 26.587053
# epoch: 487 	training Loss: 27.091837
# epoch: 488 	training Loss: 26.984711
# epoch: 489 	training Loss: 28.426865
# epoch: 490 	training Loss: 26.465256
# epoch: 491 	training Loss: 26.678999
# epoch: 492 	training Loss: 26.811119
# epoch: 493 	training Loss: 28.380226
# epoch: 494 	training Loss: 26.521931
# epoch: 495 	training Loss: 26.568176
# epoch: 496 	training Loss: 26.504503
# epoch: 497 	training Loss: 28.045712
# epoch: 498 	training Loss: 26.336353
# epoch: 499 	training Loss: 26.654366
# epoch: 500 	training Loss: 26.608360
# epoch: 501 	training Loss: 28.089384
# epoch: 502 	training Loss: 26.088797
# epoch: 503 	training Loss: 26.032394
# epoch: 504 	training Loss: 25.998310
# epoch: 505 	training Loss: 27.709040
# epoch: 506 	training Loss: 25.971722
# epoch: 507 	training Loss: 26.488176
# epoch: 508 	training Loss: 26.479151
# epoch: 509 	training Loss: 27.306246
# epoch: 510 	training Loss: 25.210295
# epoch: 511 	training Loss: 25.509094
# epoch: 512 	training Loss: 25.443079
# epoch: 513 	training Loss: 27.170809
# epoch: 514 	training Loss: 25.892733
# epoch: 515 	training Loss: 27.474041
# epoch: 516 	training Loss: 26.941147
# epoch: 517 	training Loss: 25.420256
# epoch: 518 	training Loss: 24.596760
# epoch: 519 	training Loss: 26.123302
# epoch: 520 	training Loss: 24.119493
# epoch: 521 	training Loss: 24.844900
# epoch: 522 	training Loss: 23.978172
# epoch: 523 	training Loss: 24.960146
# epoch: 524 	training Loss: 24.119307
# epoch: 525 	training Loss: 25.902407
# epoch: 526 	training Loss: 24.016699
# epoch: 527 	training Loss: 25.161165
# epoch: 528 	training Loss: 24.295839
# epoch: 529 	training Loss: 26.581078
# epoch: 530 	training Loss: 23.836369
# epoch: 531 	training Loss: 23.939514
# epoch: 532 	training Loss: 23.526413
# epoch: 533 	training Loss: 24.359358
# epoch: 534 	training Loss: 23.867193
# epoch: 535 	training Loss: 24.027037
# epoch: 536 	training Loss: 23.367163
# epoch: 537 	training Loss: 22.821472
# epoch: 538 	training Loss: 22.557449
# epoch: 539 	training Loss: 22.587786
# epoch: 540 	training Loss: 22.835258
# epoch: 541 	training Loss: 23.550430
# epoch: 542 	training Loss: 24.213308
# epoch: 543 	training Loss: 23.183966
# epoch: 544 	training Loss: 23.585011
# epoch: 545 	training Loss: 23.965328
# epoch: 546 	training Loss: 28.502069
# epoch: 547 	training Loss: 22.142092
# epoch: 548 	training Loss: 22.038038
# epoch: 549 	training Loss: 23.023329
# epoch: 550 	training Loss: 23.785170
# epoch: 551 	training Loss: 23.532192
# epoch: 552 	training Loss: 22.906319
# epoch: 553 	training Loss: 22.555937
# epoch: 554 	training Loss: 24.733568
# epoch: 555 	training Loss: 22.519527
# epoch: 556 	training Loss: 24.382889
# epoch: 557 	training Loss: 23.767221
# epoch: 558 	training Loss: 25.992018
# epoch: 559 	training Loss: 22.687441
# epoch: 560 	training Loss: 22.590343
# epoch: 561 	training Loss: 22.728111
# epoch: 562 	training Loss: 25.342243
# epoch: 563 	training Loss: 21.918343
# epoch: 564 	training Loss: 22.677355
# epoch: 565 	training Loss: 23.136759
# epoch: 566 	training Loss: 24.987175
# epoch: 567 	training Loss: 22.345343
# epoch: 568 	training Loss: 22.530746
# epoch: 569 	training Loss: 22.441694
# epoch: 570 	training Loss: 24.987036
# epoch: 571 	training Loss: 21.863573
# epoch: 572 	training Loss: 22.794970
# epoch: 573 	training Loss: 23.363733
# epoch: 574 	training Loss: 23.788797
# epoch: 575 	training Loss: 21.696287
# epoch: 576 	training Loss: 22.454649
# epoch: 577 	training Loss: 21.686083
# epoch: 578 	training Loss: 23.810488
# epoch: 579 	training Loss: 21.713978
# epoch: 580 	training Loss: 23.213243
# epoch: 581 	training Loss: 24.252094
# epoch: 582 	training Loss: 22.799452
# epoch: 583 	training Loss: 21.614386
# epoch: 584 	training Loss: 23.185698
# epoch: 585 	training Loss: 20.913811
# epoch: 586 	training Loss: 22.315353
# epoch: 587 	training Loss: 20.794771
# epoch: 588 	training Loss: 22.181484
# epoch: 589 	training Loss: 20.821190
# epoch: 590 	training Loss: 22.756367
# epoch: 591 	training Loss: 21.092215
# epoch: 592 	training Loss: 23.893055
# epoch: 593 	training Loss: 20.414776
# epoch: 594 	training Loss: 22.118025
# epoch: 595 	training Loss: 20.937578
# epoch: 596 	training Loss: 23.971773
# epoch: 597 	training Loss: 20.181274
# epoch: 598 	training Loss: 21.391504
# epoch: 599 	training Loss: 21.031309
# epoch: 600 	training Loss: 23.255398
# epoch: 601 	training Loss: 20.563091
# epoch: 602 	training Loss: 22.365540
# epoch: 603 	training Loss: 20.525171
# epoch: 604 	training Loss: 22.035847
# epoch: 605 	training Loss: 20.572748
# epoch: 606 	training Loss: 22.727402
# epoch: 607 	training Loss: 20.075869
# epoch: 608 	training Loss: 21.719769
# epoch: 609 	training Loss: 20.067581
# epoch: 610 	training Loss: 22.693060
# epoch: 611 	training Loss: 20.037096
# epoch: 612 	training Loss: 21.204699
# epoch: 613 	training Loss: 20.806833
# epoch: 614 	training Loss: 23.436329
# epoch: 615 	training Loss: 19.838606
# epoch: 616 	training Loss: 20.590008
# epoch: 617 	training Loss: 20.493309
# epoch: 618 	training Loss: 23.418343
# epoch: 619 	training Loss: 19.501472
# epoch: 620 	training Loss: 20.412359
# epoch: 621 	training Loss: 20.217466
# epoch: 622 	training Loss: 24.038641
# epoch: 623 	training Loss: 18.809807
# epoch: 624 	training Loss: 19.349495
# epoch: 625 	training Loss: 20.056824
# epoch: 626 	training Loss: 22.711561
# epoch: 627 	training Loss: 19.736214
# epoch: 628 	training Loss: 21.734314
# epoch: 629 	training Loss: 23.865797
# epoch: 630 	training Loss: 21.843971
# epoch: 631 	training Loss: 20.178146
# epoch: 632 	training Loss: 23.178061
# epoch: 633 	training Loss: 18.579033
# epoch: 634 	training Loss: 18.838875
# epoch: 635 	training Loss: 19.194206
# epoch: 636 	training Loss: 22.424355
# epoch: 637 	training Loss: 18.446707
# epoch: 638 	training Loss: 19.802595
# epoch: 639 	training Loss: 19.446161
# epoch: 640 	training Loss: 23.077547
# epoch: 641 	training Loss: 18.099901
# epoch: 642 	training Loss: 18.642363
# epoch: 643 	training Loss: 19.118412
# epoch: 644 	training Loss: 21.763693
# epoch: 645 	training Loss: 18.824747
# epoch: 646 	training Loss: 19.755449
# epoch: 647 	training Loss: 19.230108
# epoch: 648 	training Loss: 22.361927
# epoch: 649 	training Loss: 17.961977
# epoch: 650 	training Loss: 18.895458
# epoch: 651 	training Loss: 18.982443
# epoch: 652 	training Loss: 22.618742
# epoch: 653 	training Loss: 17.691008
# epoch: 654 	training Loss: 18.301779
# epoch: 655 	training Loss: 18.869518
# epoch: 656 	training Loss: 21.477964
# epoch: 657 	training Loss: 18.471876
# epoch: 658 	training Loss: 19.251301
# epoch: 659 	training Loss: 19.157238
# epoch: 660 	training Loss: 21.183857
# epoch: 661 	training Loss: 19.603964
# epoch: 662 	training Loss: 21.568939
# epoch: 663 	training Loss: 23.407272
# epoch: 664 	training Loss: 18.803162
# epoch: 665 	training Loss: 18.666588
# epoch: 666 	training Loss: 21.443144
# epoch: 667 	training Loss: 17.647089
# epoch: 668 	training Loss: 18.055119
# epoch: 669 	training Loss: 18.022074
# epoch: 670 	training Loss: 20.617508
# epoch: 671 	training Loss: 17.522295
# epoch: 672 	training Loss: 19.095070
# epoch: 673 	training Loss: 17.936737
# epoch: 674 	training Loss: 20.817595
# epoch: 675 	training Loss: 17.248474
# epoch: 676 	training Loss: 18.455389
# epoch: 677 	training Loss: 18.029539
# epoch: 678 	training Loss: 20.542931
# epoch: 679 	training Loss: 17.487553
# epoch: 680 	training Loss: 18.428383
# epoch: 681 	training Loss: 17.912312
# epoch: 682 	training Loss: 20.324236
# epoch: 683 	training Loss: 17.373850
# epoch: 684 	training Loss: 18.414238
# epoch: 685 	training Loss: 17.781082
# epoch: 686 	training Loss: 20.199438
# epoch: 687 	training Loss: 17.216261
# epoch: 688 	training Loss: 18.287792
# epoch: 689 	training Loss: 17.665375
# epoch: 690 	training Loss: 20.022778
# epoch: 691 	training Loss: 17.167469
# epoch: 692 	training Loss: 18.200361
# epoch: 693 	training Loss: 17.570192
# epoch: 694 	training Loss: 19.779112
# epoch: 695 	training Loss: 17.149349
# epoch: 696 	training Loss: 18.156652
# epoch: 697 	training Loss: 17.432690
# epoch: 698 	training Loss: 19.523746
# epoch: 699 	training Loss: 17.029146
# epoch: 700 	training Loss: 18.134121
# epoch: 701 	training Loss: 17.226070
# epoch: 702 	training Loss: 19.387196
# epoch: 703 	training Loss: 16.804550
# epoch: 704 	training Loss: 18.079632
# epoch: 705 	training Loss: 17.060812
# epoch: 706 	training Loss: 19.202402
# epoch: 707 	training Loss: 16.706142
# epoch: 708 	training Loss: 17.932201
# epoch: 709 	training Loss: 16.982512
# epoch: 710 	training Loss: 18.925962
# epoch: 711 	training Loss: 16.755863
# epoch: 712 	training Loss: 17.910358
# epoch: 713 	training Loss: 16.937973
# epoch: 714 	training Loss: 18.634504
# epoch: 715 	training Loss: 16.708740
# epoch: 716 	training Loss: 17.775877
# epoch: 717 	training Loss: 16.775314
# epoch: 718 	training Loss: 18.358572
# epoch: 719 	training Loss: 16.572470
# epoch: 720 	training Loss: 17.897253
# epoch: 721 	training Loss: 16.488586
# epoch: 722 	training Loss: 18.473295
# epoch: 723 	training Loss: 16.056097
# epoch: 724 	training Loss: 17.723572
# epoch: 725 	training Loss: 16.188251
# epoch: 726 	training Loss: 18.238697
# epoch: 727 	training Loss: 16.021439
# epoch: 728 	training Loss: 17.487032
# epoch: 729 	training Loss: 16.309093
# epoch: 730 	training Loss: 18.097494
# epoch: 731 	training Loss: 16.202021
# epoch: 732 	training Loss: 17.488377
# epoch: 733 	training Loss: 16.527431
# epoch: 734 	training Loss: 18.356030
# epoch: 735 	training Loss: 18.051100
# epoch: 736 	training Loss: 19.863108
# epoch: 737 	training Loss: 20.336943
# epoch: 738 	training Loss: 17.077909
# epoch: 739 	training Loss: 16.407249
# epoch: 740 	training Loss: 19.517809
# epoch: 741 	training Loss: 14.997435
# epoch: 742 	training Loss: 14.938949
# epoch: 743 	training Loss: 14.911501
# epoch: 744 	training Loss: 15.959515
# epoch: 745 	training Loss: 15.403100
# epoch: 746 	training Loss: 17.365572
# epoch: 747 	training Loss: 15.243752
# epoch: 748 	training Loss: 17.501667
# epoch: 749 	training Loss: 14.770130
# epoch: 750 	training Loss: 16.755407
# epoch: 751 	training Loss: 14.828058
# epoch: 752 	training Loss: 16.941059
# epoch: 753 	training Loss: 14.795105
# epoch: 754 	training Loss: 16.581055
# epoch: 755 	training Loss: 14.985927
# epoch: 756 	training Loss: 16.661963
# epoch: 757 	training Loss: 15.020874
# epoch: 758 	training Loss: 16.388847
# epoch: 759 	training Loss: 15.172878
# epoch: 760 	training Loss: 16.573372
# epoch: 761 	training Loss: 15.199956
# epoch: 762 	training Loss: 16.364746
# epoch: 763 	training Loss: 15.406906
# epoch: 764 	training Loss: 16.864918
# epoch: 765 	training Loss: 16.884087
# epoch: 766 	training Loss: 18.220268
# epoch: 767 	training Loss: 19.015593
# epoch: 768 	training Loss: 16.116617
# epoch: 769 	training Loss: 15.323338
# epoch: 770 	training Loss: 18.125145
# epoch: 771 	training Loss: 14.370314
# epoch: 772 	training Loss: 14.634556
# epoch: 773 	training Loss: 14.224995
# epoch: 774 	training Loss: 15.010067
# epoch: 775 	training Loss: 14.532710
# epoch: 776 	training Loss: 16.456650
# epoch: 777 	training Loss: 14.334059
# epoch: 778 	training Loss: 16.555918
# epoch: 779 	training Loss: 13.917289
# epoch: 780 	training Loss: 15.418245
# epoch: 781 	training Loss: 14.122153
# epoch: 782 	training Loss: 16.034380
# epoch: 783 	training Loss: 13.928921
# epoch: 784 	training Loss: 14.935972
# epoch: 785 	training Loss: 14.303346
# epoch: 786 	training Loss: 16.087313
# epoch: 787 	training Loss: 13.794408
# epoch: 788 	training Loss: 13.793064
# epoch: 789 	training Loss: 13.614568
# epoch: 790 	training Loss: 14.149302
# epoch: 791 	training Loss: 14.341993
# epoch: 792 	training Loss: 15.029855
# epoch: 793 	training Loss: 14.960011
# epoch: 794 	training Loss: 14.945008
# epoch: 795 	training Loss: 16.156332
# epoch: 796 	training Loss: 15.449423
# epoch: 797 	training Loss: 17.105343
# epoch: 798 	training Loss: 15.996312
# epoch: 799 	training Loss: 16.478436
# epoch: 800 	training Loss: 16.536245
# epoch: 801 	training Loss: 16.016836
# epoch: 802 	training Loss: 15.341288
# epoch: 803 	training Loss: 15.979648
# epoch: 804 	training Loss: 14.657336
# epoch: 805 	training Loss: 15.094866
# epoch: 806 	training Loss: 14.787522
# epoch: 807 	training Loss: 14.934731
# epoch: 808 	training Loss: 15.003421
# epoch: 809 	training Loss: 14.796233
# epoch: 810 	training Loss: 14.695517
# epoch: 811 	training Loss: 14.641605
# epoch: 812 	training Loss: 14.470678
# epoch: 813 	training Loss: 14.603764
# epoch: 814 	training Loss: 14.430746
# epoch: 815 	training Loss: 14.558105
# epoch: 816 	training Loss: 14.520766
# epoch: 817 	training Loss: 14.463775
# epoch: 818 	training Loss: 14.495984
# epoch: 819 	training Loss: 14.307112
# epoch: 820 	training Loss: 14.310131
# epoch: 821 	training Loss: 14.175880
# epoch: 822 	training Loss: 14.152244
# epoch: 823 	training Loss: 14.103587
# epoch: 824 	training Loss: 14.096485
# epoch: 825 	training Loss: 14.037842
# epoch: 826 	training Loss: 14.084596
# epoch: 827 	training Loss: 13.948008
# epoch: 828 	training Loss: 14.031603
# epoch: 829 	training Loss: 13.827036
# epoch: 830 	training Loss: 13.914685
# epoch: 831 	training Loss: 13.688498
# epoch: 832 	training Loss: 13.777464
# epoch: 833 	training Loss: 13.540028
# epoch: 834 	training Loss: 13.674183
# epoch: 835 	training Loss: 13.428318
# epoch: 836 	training Loss: 13.669369
# epoch: 837 	training Loss: 13.398507
# epoch: 838 	training Loss: 13.632366
# epoch: 839 	training Loss: 13.210473
# epoch: 840 	training Loss: 13.452572
# epoch: 841 	training Loss: 13.186707
# epoch: 842 	training Loss: 13.409194
# epoch: 843 	training Loss: 13.097579
# epoch: 844 	training Loss: 13.336252
# epoch: 845 	training Loss: 13.152975
# epoch: 846 	training Loss: 13.359356
# epoch: 847 	training Loss: 13.099589
# epoch: 848 	training Loss: 13.425090
# epoch: 849 	training Loss: 13.254067
# epoch: 850 	training Loss: 13.472946
# epoch: 851 	training Loss: 13.190850
# epoch: 852 	training Loss: 13.311275
# epoch: 853 	training Loss: 13.170528
# epoch: 854 	training Loss: 13.214981
# epoch: 855 	training Loss: 13.207577
# epoch: 856 	training Loss: 13.204018
# epoch: 857 	training Loss: 13.164044
# epoch: 858 	training Loss: 13.226388
# epoch: 859 	training Loss: 13.093539
# epoch: 860 	training Loss: 13.381282
# epoch: 861 	training Loss: 13.130482
# epoch: 862 	training Loss: 13.381010
# epoch: 863 	training Loss: 12.838140
# epoch: 864 	training Loss: 12.987571
# epoch: 865 	training Loss: 12.599093
# epoch: 866 	training Loss: 12.713884
# epoch: 867 	training Loss: 12.489190
# epoch: 868 	training Loss: 12.758436
# epoch: 869 	training Loss: 12.708329
# epoch: 870 	training Loss: 12.971461
# epoch: 871 	training Loss: 12.643194
# epoch: 872 	training Loss: 12.872387
# epoch: 873 	training Loss: 12.467561
# epoch: 874 	training Loss: 12.671809
# epoch: 875 	training Loss: 12.406397
# epoch: 876 	training Loss: 12.661925
# epoch: 877 	training Loss: 12.398773
# epoch: 878 	training Loss: 12.662010
# epoch: 879 	training Loss: 12.367152
# epoch: 880 	training Loss: 12.611986
# epoch: 881 	training Loss: 12.309705
# epoch: 882 	training Loss: 12.537015
# epoch: 883 	training Loss: 12.279927
# epoch: 884 	training Loss: 12.485969
# epoch: 885 	training Loss: 12.237708
# epoch: 886 	training Loss: 12.514672
# epoch: 887 	training Loss: 12.431511
# epoch: 888 	training Loss: 12.600988
# epoch: 889 	training Loss: 12.338764
# epoch: 890 	training Loss: 12.458804
# epoch: 891 	training Loss: 12.278710
# epoch: 892 	training Loss: 12.317198
# epoch: 893 	training Loss: 12.184957
# epoch: 894 	training Loss: 12.401880
# epoch: 895 	training Loss: 12.496566
# epoch: 896 	training Loss: 12.570643
# epoch: 897 	training Loss: 12.440110
# epoch: 898 	training Loss: 12.567998
# epoch: 899 	training Loss: 12.383626
# epoch: 900 	training Loss: 12.463131
# epoch: 901 	training Loss: 12.304066
# epoch: 902 	training Loss: 12.381316
# epoch: 903 	training Loss: 12.228651
# epoch: 904 	training Loss: 12.320362
# epoch: 905 	training Loss: 12.148865
# epoch: 906 	training Loss: 12.277102
# epoch: 907 	training Loss: 12.061749
# epoch: 908 	training Loss: 12.242034
# epoch: 909 	training Loss: 11.959683
# epoch: 910 	training Loss: 12.194264
# epoch: 911 	training Loss: 11.829263
# epoch: 912 	training Loss: 12.104280
# epoch: 913 	training Loss: 11.670575
# epoch: 914 	training Loss: 11.970620
# epoch: 915 	training Loss: 11.496211
# epoch: 916 	training Loss: 11.831131
# epoch: 917 	training Loss: 11.335781
# epoch: 918 	training Loss: 11.723135
# epoch: 919 	training Loss: 11.212561
# epoch: 920 	training Loss: 11.688360
# epoch: 921 	training Loss: 11.176989
# epoch: 922 	training Loss: 11.837217
# epoch: 923 	training Loss: 32.264149
# epoch: 924 	training Loss: 18.836727
# epoch: 925 	training Loss: 15.754928
# epoch: 926 	training Loss: 14.393620
# epoch: 927 	training Loss: 17.215757
# epoch: 928 	training Loss: 13.049140
# epoch: 929 	training Loss: 17.236975
# epoch: 930 	training Loss: 13.876803
# epoch: 931 	training Loss: 16.702715
# epoch: 932 	training Loss: 13.312948
# epoch: 933 	training Loss: 19.319206
# epoch: 934 	training Loss: 16.349058
# epoch: 935 	training Loss: 21.732821
# epoch: 936 	training Loss: 15.187625
# epoch: 937 	training Loss: 17.140396
# epoch: 938 	training Loss: 15.839643
# epoch: 939 	training Loss: 19.300196
# epoch: 940 	training Loss: 15.030544
# epoch: 941 	training Loss: 16.635738
# epoch: 942 	training Loss: 15.036151
# epoch: 943 	training Loss: 17.534735
# epoch: 944 	training Loss: 14.670167
# epoch: 945 	training Loss: 16.946115
# epoch: 946 	training Loss: 14.514083
# epoch: 947 	training Loss: 16.413923
# epoch: 948 	training Loss: 14.431895
# epoch: 949 	training Loss: 16.533049
# epoch: 950 	training Loss: 14.120534
# epoch: 951 	training Loss: 15.692448
# epoch: 952 	training Loss: 14.027075
# epoch: 953 	training Loss: 15.981423
# epoch: 954 	training Loss: 13.716885
# epoch: 955 	training Loss: 15.269714
# epoch: 956 	training Loss: 13.648527
# epoch: 957 	training Loss: 15.498981
# epoch: 958 	training Loss: 13.450667
# epoch: 959 	training Loss: 15.063244
# epoch: 960 	training Loss: 13.383876
# epoch: 961 	training Loss: 15.152003
# epoch: 962 	training Loss: 13.226414
# epoch: 963 	training Loss: 14.838689
# epoch: 964 	training Loss: 13.062938
# epoch: 965 	training Loss: 14.579555
# epoch: 966 	training Loss: 12.536878
# epoch: 967 	training Loss: 13.527184
# epoch: 968 	training Loss: 11.325346
# epoch: 969 	training Loss: 12.017456
# epoch: 970 	training Loss: 10.876519
# epoch: 971 	training Loss: 11.890399
# epoch: 972 	training Loss: 10.931311
# epoch: 973 	training Loss: 12.131269
# epoch: 974 	training Loss: 10.956791
# epoch: 975 	training Loss: 12.199271
# epoch: 976 	training Loss: 10.921796
# epoch: 977 	training Loss: 12.168530
# epoch: 978 	training Loss: 10.889684
# epoch: 979 	training Loss: 12.150752
# epoch: 980 	training Loss: 10.857937
# epoch: 981 	training Loss: 12.132729
# epoch: 982 	training Loss: 10.823236
# epoch: 983 	training Loss: 12.112023
# epoch: 984 	training Loss: 10.790203
# epoch: 985 	training Loss: 12.094937
# epoch: 986 	training Loss: 10.758239
# epoch: 987 	training Loss: 12.078234
# epoch: 988 	training Loss: 10.728889
# epoch: 989 	training Loss: 12.061856
# epoch: 990 	training Loss: 10.700960
# epoch: 991 	training Loss: 12.038679
# epoch: 992 	training Loss: 10.676236
# epoch: 993 	training Loss: 12.004672
# epoch: 994 	training Loss: 10.648227
# epoch: 995 	training Loss: 11.955650
# epoch: 996 	training Loss: 10.615001
# epoch: 997 	training Loss: 11.912240
# epoch: 998 	training Loss: 10.610791
# epoch: 999 	training Loss: 11.908500
# epoch: 1000 	training Loss: 10.638480
# epoch: 1001 	training Loss: 11.927914
# epoch: 1002 	training Loss: 10.690115
# epoch: 1003 	training Loss: 11.965633
# epoch: 1004 	training Loss: 10.789282
# epoch: 1005 	training Loss: 12.042287
# epoch: 1006 	training Loss: 10.919678
# epoch: 1007 	training Loss: 12.097947
# epoch: 1008 	training Loss: 11.148010
# epoch: 1009 	training Loss: 12.197238
# epoch: 1010 	training Loss: 11.350462
# epoch: 1011 	training Loss: 12.149792
# epoch: 1012 	training Loss: 11.445598
# epoch: 1013 	training Loss: 12.163046
# epoch: 1014 	training Loss: 12.002120
# epoch: 1015 	training Loss: 12.998993
# epoch: 1016 	training Loss: 13.590837
# epoch: 1017 	training Loss: 13.278394
# epoch: 1018 	training Loss: 13.347044
# epoch: 1019 	training Loss: 11.832499
# epoch: 1020 	training Loss: 11.509989
# epoch: 1021 	training Loss: 11.487495
# epoch: 1022 	training Loss: 10.961986
# epoch: 1023 	training Loss: 11.052760
# epoch: 1024 	training Loss: 10.828019
# epoch: 1025 	training Loss: 10.873261
# epoch: 1026 	training Loss: 10.934152
# epoch: 1027 	training Loss: 10.838222
# epoch: 1028 	training Loss: 11.110731
# epoch: 1029 	training Loss: 10.765424
# epoch: 1030 	training Loss: 11.093359
# epoch: 1031 	training Loss: 10.539756
# epoch: 1032 	training Loss: 10.811024
# epoch: 1033 	training Loss: 10.352832
# epoch: 1034 	training Loss: 10.604816
# epoch: 1035 	training Loss: 10.298702
# epoch: 1036 	training Loss: 10.544298
# epoch: 1037 	training Loss: 10.322731
# epoch: 1038 	training Loss: 10.559388
# epoch: 1039 	training Loss: 10.375457
# epoch: 1040 	training Loss: 10.588860
# epoch: 1041 	training Loss: 10.428249
# epoch: 1042 	training Loss: 10.611593
# epoch: 1043 	training Loss: 10.452689
# epoch: 1044 	training Loss: 10.608059
# epoch: 1045 	training Loss: 10.444130
# epoch: 1046 	training Loss: 10.585774
# epoch: 1047 	training Loss: 10.409245
# epoch: 1048 	training Loss: 10.553771
# epoch: 1049 	training Loss: 10.357301
# epoch: 1050 	training Loss: 10.517593
# epoch: 1051 	training Loss: 10.294861
# epoch: 1052 	training Loss: 10.475234
# epoch: 1053 	training Loss: 10.225255
# epoch: 1054 	training Loss: 10.424159
# epoch: 1055 	training Loss: 10.150826
# epoch: 1056 	training Loss: 10.365668
# epoch: 1057 	training Loss: 10.078703
# epoch: 1058 	training Loss: 10.307158
# epoch: 1059 	training Loss: 10.014875
# epoch: 1060 	training Loss: 10.253601
# epoch: 1061 	training Loss: 9.959386
# epoch: 1062 	training Loss: 10.205030
# epoch: 1063 	training Loss: 9.910360
# epoch: 1064 	training Loss: 10.160351
# epoch: 1065 	training Loss: 9.867061
# epoch: 1066 	training Loss: 10.119519
# epoch: 1067 	training Loss: 9.829126
# epoch: 1068 	training Loss: 10.082508
# epoch: 1069 	training Loss: 9.796070
# epoch: 1070 	training Loss: 10.048997
# epoch: 1071 	training Loss: 9.767049
# epoch: 1072 	training Loss: 10.018365
# epoch: 1073 	training Loss: 9.741178
# epoch: 1074 	training Loss: 9.990035
# epoch: 1075 	training Loss: 9.717495
# epoch: 1076 	training Loss: 9.963427
# epoch: 1077 	training Loss: 9.694998
# epoch: 1078 	training Loss: 9.937921
# epoch: 1079 	training Loss: 9.672547
# epoch: 1080 	training Loss: 9.912747
# epoch: 1081 	training Loss: 9.648968
# epoch: 1082 	training Loss: 9.887026
# epoch: 1083 	training Loss: 9.623109
# epoch: 1084 	training Loss: 9.859789
# epoch: 1085 	training Loss: 9.593930
# epoch: 1086 	training Loss: 9.830064
# epoch: 1087 	training Loss: 9.560541
# epoch: 1088 	training Loss: 9.796890
# epoch: 1089 	training Loss: 9.522212
# epoch: 1090 	training Loss: 9.759379
# epoch: 1091 	training Loss: 9.478255
# epoch: 1092 	training Loss: 9.716613
# epoch: 1093 	training Loss: 9.427755
# epoch: 1094 	training Loss: 9.667477
# epoch: 1095 	training Loss: 9.369360
# epoch: 1096 	training Loss: 9.610506
# epoch: 1097 	training Loss: 9.301879
# epoch: 1098 	training Loss: 9.544848
# epoch: 1099 	training Loss: 9.227114
# epoch: 1100 	training Loss: 9.473784
# epoch: 1101 	training Loss: 9.150100
# epoch: 1102 	training Loss: 9.403002
# epoch: 1103 	training Loss: 9.066410
# epoch: 1104 	training Loss: 9.324990
# epoch: 1105 	training Loss: 8.970133
# epoch: 1106 	training Loss: 9.233289
# epoch: 1107 	training Loss: 8.869357
# epoch: 1108 	training Loss: 9.151518
# epoch: 1109 	training Loss: 8.801542
# epoch: 1110 	training Loss: 9.192542
# epoch: 1111 	training Loss: 8.924069
# epoch: 1112 	training Loss: 9.782797
# epoch: 1113 	training Loss: 9.548996
# epoch: 1114 	training Loss: 11.856076
# epoch: 1115 	training Loss: 10.309793
# epoch: 1116 	training Loss: 13.457727
# epoch: 1117 	training Loss: 9.816177
# epoch: 1118 	training Loss: 11.238516
# epoch: 1119 	training Loss: 9.712893
# epoch: 1120 	training Loss: 11.215796
# epoch: 1121 	training Loss: 9.629686
# epoch: 1122 	training Loss: 11.114208
# epoch: 1123 	training Loss: 9.563583
# epoch: 1124 	training Loss: 11.020071
# epoch: 1125 	training Loss: 9.504510
# epoch: 1126 	training Loss: 10.910308
# epoch: 1127 	training Loss: 9.462854
# epoch: 1128 	training Loss: 10.827477
# epoch: 1129 	training Loss: 9.424299
# epoch: 1130 	training Loss: 10.746784
# epoch: 1131 	training Loss: 9.392294
# epoch: 1132 	training Loss: 10.688498
# epoch: 1133 	training Loss: 9.364228
# epoch: 1134 	training Loss: 10.638586
# epoch: 1135 	training Loss: 9.340012
# epoch: 1136 	training Loss: 10.597091
# epoch: 1137 	training Loss: 9.317793
# epoch: 1138 	training Loss: 10.560184
# epoch: 1139 	training Loss: 9.299631
# epoch: 1140 	training Loss: 10.530664
# epoch: 1141 	training Loss: 9.283916
# epoch: 1142 	training Loss: 10.503292
# epoch: 1143 	training Loss: 9.270884
# epoch: 1144 	training Loss: 10.480876
# epoch: 1145 	training Loss: 9.261528
# epoch: 1146 	training Loss: 10.460853
# epoch: 1147 	training Loss: 9.249997
# epoch: 1148 	training Loss: 10.437029
# epoch: 1149 	training Loss: 9.237826
# epoch: 1150 	training Loss: 10.416063
# epoch: 1151 	training Loss: 9.227936
# epoch: 1152 	training Loss: 10.398840
# epoch: 1153 	training Loss: 9.220616
# epoch: 1154 	training Loss: 10.382557
# epoch: 1155 	training Loss: 9.214412
# epoch: 1156 	training Loss: 10.366027
# epoch: 1157 	training Loss: 9.208545
# epoch: 1158 	training Loss: 10.350798
# epoch: 1159 	training Loss: 9.202787
# epoch: 1160 	training Loss: 10.336347
# epoch: 1161 	training Loss: 9.194797
# epoch: 1162 	training Loss: 10.318216
# epoch: 1163 	training Loss: 9.183651
# epoch: 1164 	training Loss: 10.296272
# epoch: 1165 	training Loss: 9.170127
# epoch: 1166 	training Loss: 10.273001
# epoch: 1167 	training Loss: 9.154847
# epoch: 1168 	training Loss: 10.249454
# epoch: 1169 	training Loss: 9.138034
# epoch: 1170 	training Loss: 10.225532
# epoch: 1171 	training Loss: 9.119877
# epoch: 1172 	training Loss: 10.200979
# epoch: 1173 	training Loss: 9.100783
# epoch: 1174 	training Loss: 10.175819
# epoch: 1175 	training Loss: 9.081357
# epoch: 1176 	training Loss: 10.150303
# epoch: 1177 	training Loss: 9.062222
# epoch: 1178 	training Loss: 10.124794
# epoch: 1179 	training Loss: 9.043888
# epoch: 1180 	training Loss: 10.099632
# epoch: 1181 	training Loss: 9.026736
# epoch: 1182 	training Loss: 10.075155
# epoch: 1183 	training Loss: 9.011109
# epoch: 1184 	training Loss: 10.051767
# epoch: 1185 	training Loss: 8.997523
# epoch: 1186 	training Loss: 10.030149
# epoch: 1187 	training Loss: 8.987079
# epoch: 1188 	training Loss: 10.011436
# epoch: 1189 	training Loss: 8.982153
# epoch: 1190 	training Loss: 9.997006
# epoch: 1191 	training Loss: 8.986046
# epoch: 1192 	training Loss: 9.986133
# epoch: 1193 	training Loss: 8.997381
# epoch: 1194 	training Loss: 9.976970
# epoch: 1195 	training Loss: 9.013919
# epoch: 1196 	training Loss: 9.967028
# epoch: 1197 	training Loss: 9.025602
# epoch: 1198 	training Loss: 9.952734
# epoch: 1199 	training Loss: 9.037708
# epoch: 1200 	training Loss: 9.946954
# epoch: 1201 	training Loss: 9.047499
# epoch: 1202 	training Loss: 9.937387
# epoch: 1203 	training Loss: 9.038963
# epoch: 1204 	training Loss: 9.910321
# epoch: 1205 	training Loss: 9.006459
# epoch: 1206 	training Loss: 9.869080
# epoch: 1207 	training Loss: 8.959174
# epoch: 1208 	training Loss: 9.822989
# epoch: 1209 	training Loss: 8.909866
# epoch: 1210 	training Loss: 9.782183
# epoch: 1211 	training Loss: 8.853496
# epoch: 1212 	training Loss: 9.738271
# epoch: 1213 	training Loss: 8.779991
# epoch: 1214 	training Loss: 9.686816
# epoch: 1215 	training Loss: 8.726154
# epoch: 1216 	training Loss: 9.656802
# epoch: 1217 	training Loss: 8.677885
# epoch: 1218 	training Loss: 9.620521
# epoch: 1219 	training Loss: 8.625349
# epoch: 1220 	training Loss: 9.573510
# epoch: 1221 	training Loss: 8.574816
# epoch: 1222 	training Loss: 9.521477
# epoch: 1223 	training Loss: 8.525002
# epoch: 1224 	training Loss: 9.466734
# epoch: 1225 	training Loss: 8.491421
# epoch: 1226 	training Loss: 9.427731
# epoch: 1227 	training Loss: 8.467926
# epoch: 1228 	training Loss: 9.395720
# epoch: 1229 	training Loss: 8.453095
# epoch: 1230 	training Loss: 9.372435
# epoch: 1231 	training Loss: 8.452092
# epoch: 1232 	training Loss: 9.368529
# epoch: 1233 	training Loss: 8.487666
# epoch: 1234 	training Loss: 9.407393
# epoch: 1235 	training Loss: 8.559891
# epoch: 1236 	training Loss: 9.481999
# epoch: 1237 	training Loss: 8.706573
# epoch: 1238 	training Loss: 9.609796
# epoch: 1239 	training Loss: 8.935611
# epoch: 1240 	training Loss: 9.713673
# epoch: 1241 	training Loss: 9.067791
# epoch: 1242 	training Loss: 9.609820
# epoch: 1243 	training Loss: 9.120785
# epoch: 1244 	training Loss: 9.554258
# epoch: 1245 	training Loss: 9.207442
# epoch: 1246 	training Loss: 9.547976
# epoch: 1247 	training Loss: 9.401407
# epoch: 1248 	training Loss: 9.602905
# epoch: 1249 	training Loss: 9.554916
# epoch: 1250 	training Loss: 9.638782
# epoch: 1251 	training Loss: 9.700560
# epoch: 1252 	training Loss: 9.646254
# epoch: 1253 	training Loss: 9.682006
# epoch: 1254 	training Loss: 9.608725
# epoch: 1255 	training Loss: 9.753068
# epoch: 1256 	training Loss: 9.916132
# epoch: 1257 	training Loss: 10.509732
# epoch: 1258 	training Loss: 10.266328
# epoch: 1259 	training Loss: 10.400125
# epoch: 1260 	training Loss: 9.226896
# ...
# epoch: 1588 	training Loss: 7.288825
# epoch: 1589 	training Loss: 8.543664
# epoch: 1590 	training Loss: 7.202397
# epoch: 1591 	training Loss: 7.736722
# epoch: 1592 	training Loss: 6.931021
# epoch: 1593 	training Loss: 7.552445
# epoch: 1594 	training Loss: 6.843233
# epoch: 1595 	training Loss: 7.276074
# epoch: 1596 	training Loss: 6.709558
# epoch: 1597 	training Loss: 7.029537
# epoch: 1598 	training Loss: 6.602016
# epoch: 1599 	training Loss: 6.877435
# epoch: 1600 	training Loss: 6.508936
# epoch: 1601 	training Loss: 6.752311
# epoch: 1602 	training Loss: 6.433253
# epoch: 1603 	training Loss: 6.659923
# epoch: 1604 	training Loss: 6.360137
# epoch: 1605 	training Loss: 6.589564
# epoch: 1606 	training Loss: 6.287131
# epoch: 1607 	training Loss: 6.544866
# epoch: 1608 	training Loss: 6.246057
# epoch: 1609 	training Loss: 6.547480
# epoch: 1610 	training Loss: 6.241157
# epoch: 1611 	training Loss: 6.583418
# epoch: 1612 	training Loss: 6.252114
# epoch: 1613 	training Loss: 6.638662
# epoch: 1614 	training Loss: 6.272677
# epoch: 1615 	training Loss: 6.714938
# epoch: 1616 	training Loss: 6.308259
# epoch: 1617 	training Loss: 6.822320
# epoch: 1618 	training Loss: 6.364939
# epoch: 1619 	training Loss: 6.966877
# epoch: 1620 	training Loss: 6.473390
# epoch: 1621 	training Loss: 7.195585
# epoch: 1622 	training Loss: 6.670012
# epoch: 1623 	training Loss: 7.486789
# epoch: 1624 	training Loss: 7.029920
# epoch: 1625 	training Loss: 7.847774
# epoch: 1626 	training Loss: 7.364087
# epoch: 1627 	training Loss: 8.112099
# epoch: 1628 	training Loss: 7.996623
# epoch: 1629 	training Loss: 9.534499
# epoch: 1630 	training Loss: 8.648933
# epoch: 1631 	training Loss: 7.707468
# epoch: 1632 	training Loss: 6.951408
# epoch: 1633 	training Loss: 6.898435
# epoch: 1634 	training Loss: 6.890391
# epoch: 1635 	training Loss: 7.026309
# epoch: 1636 	training Loss: 7.055259
# epoch: 1637 	training Loss: 6.950740
# epoch: 1638 	training Loss: 6.999234
# epoch: 1639 	training Loss: 6.863980
# epoch: 1640 	training Loss: 6.843038
# epoch: 1641 	training Loss: 6.745433
# epoch: 1642 	training Loss: 6.774861
# epoch: 1643 	training Loss: 6.759964
# epoch: 1644 	training Loss: 6.931671
# epoch: 1645 	training Loss: 7.071245
# epoch: 1646 	training Loss: 7.489061
# epoch: 1647 	training Loss: 7.626675
# epoch: 1648 	training Loss: 7.969849
# epoch: 1649 	training Loss: 7.562090
# epoch: 1650 	training Loss: 7.595908
# epoch: 1651 	training Loss: 7.140386
# epoch: 1652 	training Loss: 7.105974
# epoch: 1653 	training Loss: 6.794512
# epoch: 1654 	training Loss: 6.776604
# epoch: 1655 	training Loss: 6.561193
# epoch: 1656 	training Loss: 6.534532
# epoch: 1657 	training Loss: 6.395998
# epoch: 1658 	training Loss: 6.399168
# epoch: 1659 	training Loss: 6.304004
# epoch: 1660 	training Loss: 6.307211
# epoch: 1661 	training Loss: 6.256023
# epoch: 1662 	training Loss: 6.261729
# epoch: 1663 	training Loss: 6.240713
# epoch: 1664 	training Loss: 6.245612
# epoch: 1665 	training Loss: 6.251845
# epoch: 1666 	training Loss: 6.251225
# epoch: 1667 	training Loss: 6.288391
# epoch: 1668 	training Loss: 6.275732
# epoch: 1669 	training Loss: 6.353525
# epoch: 1670 	training Loss: 6.316043
# epoch: 1671 	training Loss: 6.429556
# epoch: 1672 	training Loss: 6.356659
# epoch: 1673 	training Loss: 6.492146
# epoch: 1674 	training Loss: 6.375604
# epoch: 1675 	training Loss: 6.521967
# epoch: 1676 	training Loss: 6.368501
# epoch: 1677 	training Loss: 6.535798
# epoch: 1678 	training Loss: 6.351665
# epoch: 1679 	training Loss: 6.592809
# epoch: 1680 	training Loss: 6.418101
# epoch: 1681 	training Loss: 7.069097
# epoch: 1682 	training Loss: 7.856164
# epoch: 1683 	training Loss: 15.546023
# epoch: 1684 	training Loss: 60.218948
# epoch: 1685 	training Loss: 24.464888
# epoch: 1686 	training Loss: 19.041225
# epoch: 1687 	training Loss: 18.656355
# epoch: 1688 	training Loss: 18.443607
# epoch: 1689 	training Loss: 18.298782
# epoch: 1690 	training Loss: 18.428297
# epoch: 1691 	training Loss: 17.967337
# epoch: 1692 	training Loss: 18.281656
# epoch: 1693 	training Loss: 17.336992
# epoch: 1694 	training Loss: 17.336271
# epoch: 1695 	training Loss: 16.967897
# epoch: 1696 	training Loss: 16.949368
# epoch: 1697 	training Loss: 16.628914
# epoch: 1698 	training Loss: 16.549559
# epoch: 1699 	training Loss: 16.298243
# epoch: 1700 	training Loss: 16.187857
# epoch: 1701 	training Loss: 16.007286
# epoch: 1702 	training Loss: 15.901478
# epoch: 1703 	training Loss: 15.767036
# epoch: 1704 	training Loss: 15.664778
# epoch: 1705 	training Loss: 15.550349
# epoch: 1706 	training Loss: 15.448517
# epoch: 1707 	training Loss: 15.341863
# epoch: 1708 	training Loss: 15.239428
# epoch: 1709 	training Loss: 15.134671
# epoch: 1710 	training Loss: 15.030332
# epoch: 1711 	training Loss: 14.924271
# epoch: 1712 	training Loss: 14.817266
# epoch: 1713 	training Loss: 14.708963
# epoch: 1714 	training Loss: 14.599560
# epoch: 1715 	training Loss: 14.487708
# epoch: 1716 	training Loss: 14.371679
# epoch: 1717 	training Loss: 14.251607
# epoch: 1718 	training Loss: 14.129745
# epoch: 1719 	training Loss: 14.007914
# epoch: 1720 	training Loss: 13.886058
# epoch: 1721 	training Loss: 13.763951
# epoch: 1722 	training Loss: 13.641535
# epoch: 1723 	training Loss: 13.519163
# epoch: 1724 	training Loss: 13.397449
# epoch: 1725 	training Loss: 13.277309
# epoch: 1726 	training Loss: 13.159788
# epoch: 1727 	training Loss: 13.046056
# epoch: 1728 	training Loss: 12.937195
# epoch: 1729 	training Loss: 12.834135
# epoch: 1730 	training Loss: 12.737469
# epoch: 1731 	training Loss: 12.647471
# epoch: 1732 	training Loss: 12.564087
# epoch: 1733 	training Loss: 12.487023
# epoch: 1734 	training Loss: 12.415795
# epoch: 1735 	training Loss: 12.349827
# epoch: 1736 	training Loss: 12.288507
# epoch: 1737 	training Loss: 12.231264
# epoch: 1738 	training Loss: 12.177575
# epoch: 1739 	training Loss: 12.126985
# epoch: 1740 	training Loss: 12.079093
# epoch: 1741 	training Loss: 12.033557
# epoch: 1742 	training Loss: 11.990071
# epoch: 1743 	training Loss: 11.948400
# epoch: 1744 	training Loss: 11.908386
# epoch: 1745 	training Loss: 11.870034
# epoch: 1746 	training Loss: 11.834167
# epoch: 1747 	training Loss: 11.800800
# epoch: 1748 	training Loss: 11.777651
# epoch: 1749 	training Loss: 11.783091
# epoch: 1750 	training Loss: 11.868794
# epoch: 1751 	training Loss: 12.009304
# epoch: 1752 	training Loss: 12.556061
# epoch: 1753 	training Loss: 12.474603
# epoch: 1754 	training Loss: 13.318290
# epoch: 1755 	training Loss: 12.351155
# epoch: 1756 	training Loss: 12.986198
# epoch: 1757 	training Loss: 12.324276
# epoch: 1758 	training Loss: 13.049875
# epoch: 1759 	training Loss: 12.444757
# epoch: 1760 	training Loss: 13.256704
# epoch: 1761 	training Loss: 12.723331
# epoch: 1762 	training Loss: 13.763276
# epoch: 1763 	training Loss: 12.805939
# epoch: 1764 	training Loss: 13.968256
# epoch: 1765 	training Loss: 12.780186
# epoch: 1766 	training Loss: 13.895702
# epoch: 1767 	training Loss: 12.501832
# epoch: 1768 	training Loss: 13.283347
# epoch: 1769 	training Loss: 12.272333
# epoch: 1770 	training Loss: 12.983825
# epoch: 1771 	training Loss: 12.111166
# epoch: 1772 	training Loss: 12.817004
# epoch: 1773 	training Loss: 12.043091
# epoch: 1774 	training Loss: 12.746862
# epoch: 1775 	training Loss: 12.023544
# epoch: 1776 	training Loss: 12.744715
# epoch: 1777 	training Loss: 12.031878
# epoch: 1778 	training Loss: 12.786077
# epoch: 1779 	training Loss: 12.043868
# epoch: 1780 	training Loss: 12.837905
# epoch: 1781 	training Loss: 12.033934
# epoch: 1782 	training Loss: 12.860596
# epoch: 1783 	training Loss: 11.980222
# epoch: 1784 	training Loss: 12.798873
# epoch: 1785 	training Loss: 11.941675
# epoch: 1786 	training Loss: 12.762794
# epoch: 1787 	training Loss: 11.884188
# epoch: 1788 	training Loss: 12.707317
# epoch: 1789 	training Loss: 11.836066
# epoch: 1790 	training Loss: 12.669436
# epoch: 1791 	training Loss: 11.842522
# epoch: 1792 	training Loss: 12.667863
# epoch: 1793 	training Loss: 11.840671
# epoch: 1794 	training Loss: 12.679924
# epoch: 1795 	training Loss: 11.784488
# epoch: 1796 	training Loss: 12.617731
# epoch: 1797 	training Loss: 11.754733
# epoch: 1798 	training Loss: 12.588403
# epoch: 1799 	training Loss: 11.691165
# epoch: 1800 	training Loss: 12.534887
# epoch: 1801 	training Loss: 11.621648
# epoch: 1802 	training Loss: 12.482735
# epoch: 1803 	training Loss: 11.627814
# epoch: 1804 	training Loss: 12.491147
# epoch: 1805 	training Loss: 11.578025
# epoch: 1806 	training Loss: 12.447823
# epoch: 1807 	training Loss: 11.539717
# epoch: 1808 	training Loss: 12.407927
# epoch: 1809 	training Loss: 11.505424
# epoch: 1810 	training Loss: 12.374535
# epoch: 1811 	training Loss: 11.477818
# epoch: 1812 	training Loss: 12.353955
# epoch: 1813 	training Loss: 11.455515
# epoch: 1814 	training Loss: 12.344532
# epoch: 1815 	training Loss: 11.434994
# epoch: 1816 	training Loss: 12.336678
# epoch: 1817 	training Loss: 11.406810
# epoch: 1818 	training Loss: 12.312507
# epoch: 1819 	training Loss: 11.361360
# epoch: 1820 	training Loss: 12.259703
# epoch: 1821 	training Loss: 11.338155
# epoch: 1822 	training Loss: 12.244205
# epoch: 1823 	training Loss: 11.320499
# epoch: 1824 	training Loss: 12.245035
# epoch: 1825 	training Loss: 11.287683
# epoch: 1826 	training Loss: 12.221215
# epoch: 1827 	training Loss: 11.263142
# epoch: 1828 	training Loss: 12.212972
# epoch: 1829 	training Loss: 11.227826
# epoch: 1830 	training Loss: 12.182613
# epoch: 1831 	training Loss: 11.203321
# epoch: 1832 	training Loss: 12.171407
# epoch: 1833 	training Loss: 11.171920
# epoch: 1834 	training Loss: 12.144862
# epoch: 1835 	training Loss: 11.150450
# epoch: 1836 	training Loss: 12.137247
# epoch: 1837 	training Loss: 11.121095
# epoch: 1838 	training Loss: 12.113472
# epoch: 1839 	training Loss: 11.106833
# epoch: 1840 	training Loss: 12.120074
# epoch: 1841 	training Loss: 11.072131
# epoch: 1842 	training Loss: 12.085833
# epoch: 1843 	training Loss: 11.074471
# epoch: 1844 	training Loss: 12.125196
# epoch: 1845 	training Loss: 11.020783
# epoch: 1846 	training Loss: 12.052656
# epoch: 1847 	training Loss: 11.063060
# epoch: 1848 	training Loss: 12.161715
# epoch: 1849 	training Loss: 10.998023
# epoch: 1850 	training Loss: 12.074058
# epoch: 1851 	training Loss: 11.001319
# epoch: 1852 	training Loss: 12.100624
# epoch: 1853 	training Loss: 10.913733
# epoch: 1854 	training Loss: 11.957415
# epoch: 1855 	training Loss: 11.013897
# epoch: 1856 	training Loss: 12.149806
# epoch: 1857 	training Loss: 10.900805
# epoch: 1858 	training Loss: 12.001650
# epoch: 1859 	training Loss: 10.966555
# epoch: 1860 	training Loss: 12.112432
# epoch: 1861 	training Loss: 10.810780
# epoch: 1862 	training Loss: 11.866364
# epoch: 1863 	training Loss: 10.871283
# epoch: 1864 	training Loss: 11.984107
# epoch: 1865 	training Loss: 10.792667
# epoch: 1866 	training Loss: 11.894432
# epoch: 1867 	training Loss: 10.864835
# epoch: 1868 	training Loss: 12.022986
# epoch: 1869 	training Loss: 10.703702
# epoch: 1870 	training Loss: 11.776285
# epoch: 1871 	training Loss: 10.761649
# epoch: 1872 	training Loss: 11.888662
# epoch: 1873 	training Loss: 10.724280
# epoch: 1874 	training Loss: 11.881730
# epoch: 1875 	training Loss: 10.772556
# epoch: 1876 	training Loss: 11.961671
# epoch: 1877 	training Loss: 10.614724
# epoch: 1878 	training Loss: 11.711665
# epoch: 1879 	training Loss: 10.654779
# epoch: 1880 	training Loss: 11.785200
# epoch: 1881 	training Loss: 10.691405
# epoch: 1882 	training Loss: 11.896979
# epoch: 1883 	training Loss: 10.650335
# epoch: 1884 	training Loss: 11.839939
# epoch: 1885 	training Loss: 10.641266
# epoch: 1886 	training Loss: 11.840026
# epoch: 1887 	training Loss: 10.616340
# epoch: 1888 	training Loss: 11.810791
# epoch: 1889 	training Loss: 10.593977
# epoch: 1890 	training Loss: 11.781456
# epoch: 1891 	training Loss: 10.564058
# epoch: 1892 	training Loss: 11.742268
# epoch: 1893 	training Loss: 10.523719
# epoch: 1894 	training Loss: 11.685553
# epoch: 1895 	training Loss: 10.472507
# epoch: 1896 	training Loss: 11.613770
# epoch: 1897 	training Loss: 10.422784
# epoch: 1898 	training Loss: 11.547759
# epoch: 1899 	training Loss: 10.391047
# epoch: 1900 	training Loss: 11.518758
# epoch: 1901 	training Loss: 10.377140
# epoch: 1902 	training Loss: 11.525793
# epoch: 1903 	training Loss: 10.378835
# epoch: 1904 	training Loss: 11.560532
# epoch: 1905 	training Loss: 10.389026
# epoch: 1906 	training Loss: 11.605382
# epoch: 1907 	training Loss: 10.379002
# epoch: 1908 	training Loss: 11.606174
# epoch: 1909 	training Loss: 10.344201
# epoch: 1910 	training Loss: 11.555590
# epoch: 1911 	training Loss: 10.285185
# epoch: 1912 	training Loss: 11.458063
# epoch: 1913 	training Loss: 10.215453
# epoch: 1914 	training Loss: 11.340653
# epoch: 1915 	training Loss: 10.215649
# epoch: 1916 	training Loss: 11.355315
# epoch: 1917 	training Loss: 10.189630
# epoch: 1918 	training Loss: 11.343791
# epoch: 1919 	training Loss: 10.176949
# epoch: 1920 	training Loss: 11.351970
# epoch: 1921 	training Loss: 10.159407
# epoch: 1922 	training Loss: 11.360234
# epoch: 1923 	training Loss: 10.145012
# epoch: 1924 	training Loss: 11.364680
# epoch: 1925 	training Loss: 10.131864
# epoch: 1926 	training Loss: 11.367340
# epoch: 1927 	training Loss: 10.109467
# epoch: 1928 	training Loss: 11.345812
# epoch: 1929 	training Loss: 10.075113
# epoch: 1930 	training Loss: 11.298621
# epoch: 1931 	training Loss: 10.039721
# epoch: 1932 	training Loss: 11.247012
# epoch: 1933 	training Loss: 10.026130
# epoch: 1934 	training Loss: 11.236619
# epoch: 1935 	training Loss: 10.014338
# epoch: 1936 	training Loss: 11.235390
# epoch: 1937 	training Loss: 10.000370
# epoch: 1938 	training Loss: 11.232222
# epoch: 1939 	training Loss: 9.981462
# epoch: 1940 	training Loss: 11.222800
# epoch: 1941 	training Loss: 9.962779
# epoch: 1942 	training Loss: 11.212179
# epoch: 1943 	training Loss: 9.942196
# epoch: 1944 	training Loss: 11.197580
# epoch: 1945 	training Loss: 9.923688
# epoch: 1946 	training Loss: 11.183648
# epoch: 1947 	training Loss: 9.905117
# epoch: 1948 	training Loss: 11.168540
# epoch: 1949 	training Loss: 9.889484
# epoch: 1950 	training Loss: 11.156069
# epoch: 1951 	training Loss: 9.873706
# epoch: 1952 	training Loss: 11.143002
# epoch: 1953 	training Loss: 9.860865
# epoch: 1954 	training Loss: 11.132742
# epoch: 1955 	training Loss: 9.847017
# epoch: 1956 	training Loss: 11.120955
# epoch: 1957 	training Loss: 9.836104
# epoch: 1958 	training Loss: 11.111697
# epoch: 1959 	training Loss: 9.823350
# epoch: 1960 	training Loss: 11.100147
# epoch: 1961 	training Loss: 9.813346
# epoch: 1962 	training Loss: 11.091425
# epoch: 1963 	training Loss: 9.800073
# epoch: 1964 	training Loss: 11.079121
# epoch: 1965 	training Loss: 9.789903
# epoch: 1966 	training Loss: 11.071073
# epoch: 1967 	training Loss: 9.774023
# epoch: 1968 	training Loss: 11.055193
# epoch: 1969 	training Loss: 9.764812
# epoch: 1970 	training Loss: 11.049452
# epoch: 1971 	training Loss: 9.744044
# epoch: 1972 	training Loss: 11.025035
# epoch: 1973 	training Loss: 9.736342
# epoch: 1974 	training Loss: 11.021754
# epoch: 1975 	training Loss: 9.711606
# epoch: 1976 	training Loss: 10.990344
# epoch: 1977 	training Loss: 9.695867
# epoch: 1978 	training Loss: 10.971490
# epoch: 1979 	training Loss: 9.674069
# epoch: 1980 	training Loss: 10.945976
# epoch: 1981 	training Loss: 9.644753
# epoch: 1982 	training Loss: 10.903382
# epoch: 1983 	training Loss: 9.610966
# epoch: 1984 	training Loss: 10.855158
# epoch: 1985 	training Loss: 9.576202
# epoch: 1986 	training Loss: 10.805624
# epoch: 1987 	training Loss: 9.554315
# epoch: 1988 	training Loss: 10.780190
# epoch: 1989 	training Loss: 9.542558
# epoch: 1990 	training Loss: 10.776287
# epoch: 1991 	training Loss: 9.532721
# epoch: 1992 	training Loss: 10.783183
# epoch: 1993 	training Loss: 9.525054
# epoch: 1994 	training Loss: 10.799780
# epoch: 1995 	training Loss: 9.521357
# epoch: 1996 	training Loss: 10.824621
# epoch: 1997 	training Loss: 9.513367
# epoch: 1998 	training Loss: 10.835349
# epoch: 1999 	training Loss: 9.487689
# epoch: 2000 	training Loss: 10.803685

# %%
for name, param in model_RNN.named_parameters():
    if param.requires_grad:
        print(name, param.data)
        print(len(param.data))

# %%
plt.plot(range(n_epochs),losses)
plt.legend(['train'], prop={'size': 10})
plt.title('loss function', size=10)
plt.xlabel('epoch', size=10)
plt.ylabel('loss value', size=10)

# %% [markdown]
# **Response:**
#
# xxx TO DO xxx
#
# We notice that the shape of $W_{hi}$, $b_{hi}$, $W_{hh}$, $b_{hh}$ parametres is exactly (4 * hidden_size, num_directions * hidden_size), and that of $W$ and $b$ is 4*10. Which corresponds to the expected dimensions.
# With a learning rate of 0.001 and 2000 epochs we obtained a loss of appproximately 24. Therefore, we proceeded to change the learning rate in order to decrease the loss, multiplying it by 3 as it is suggested on literature. In this way we obtained a loss of 10 which is significantly better but still not completely optimized.
#
# When `lr=0.003`:
#
# ![](https://raw.githubusercontent.com/mm0806son/Images/main/202111121731136.png)

# %% [markdown]
# **Question 4:**
#
# Compare the predictions of the linear regression AR(1) and the LSTM architecture on the test dataset. Compute the root mean squared errors (for each component) between the predicted values and the truth. Plot also the histograms of the residuals (difference between prediction and truth) for the 2 models. What are the main differences between the ouputs of the AR(1) and the RNN models?

# %% [markdown]
# First, you have to transfer the prediction of your LSTM from the GPU.

# %%
# Make predictions from the AR1 and LSTM models
y_AR1_hat = model_AR1.forward(x_test)
y_RNN_hat, h_hat, c_hat = model_RNN.forward(x_test_LSTM)

# Transfer data from the GPU
y_RNN_hat = y_RNN_hat.cpu()

# %%
#############
### TO DO ###
#############
residual_AR1_x1 = y_AR1_hat[:,0] - y_test[:,0]
residual_AR1_x2 = y_AR1_hat[:,1] - y_test[:,1]
residual_AR1_x3 = y_AR1_hat[:,2] - y_test[:,2]
y_test_LSTM=y_test_LSTM.cpu()
residual_RNN = y_RNN_hat.detach().numpy()[:,0] - y_test_LSTM.detach().numpy()[:,0]



subplot(2,3,1)
plt.hist(residual_AR1_x1.detach().numpy(),50)
title('residual_AR1_x1')

subplot(2,3,2)
plt.hist(residual_AR1_x2.detach().numpy(),50)
title('residual_AR1_x2')

subplot(2,3,3)
plt.hist(residual_AR1_x3.detach().numpy(),50)
title('residual_AR1_x3')

subplot(2,3,4)
plt.hist(residual_RNN[:,0],50)
title('residual_RNN_x1')

subplot(2,3,5)
plt.hist(residual_RNN[:,1],50)
title('residual_RNN_x2')

subplot(2,3,6)
plt.hist(residual_RNN[:,2],50)
title('residual_RNN_x3')
# Out:
# Text(0.5, 1.0, 'residual_RNN_x3')

# %% [markdown]
# **Response:**
#
# xxx TO DO xxx
#
# Globally, the AR1 has a better result than RNN as the distribution appears on a smaller range, indicating the predictions are closer to the real values. In addition, we can observe a thinner distribution on the RNN results, meaning a more consistent or "precise" predicted values in contrast of the AR1 which, even though is closer to the real values, the distribution have high values all over the interval.

# %% [markdown]
# **Question 5:**
#
# Now, starting from the last value of *y_test*, use the AR(1) model and the RNN to simulate new data (e.g., a sequence of 1500 time steps). You will need to apply the models recursively. Comment the resulting trajectories: do they look like the original ones?

# %%
len_simu = 1500 # length of the simulation
x0_AR1 = y_test[-1,:] # initial condition for AR(1)
x0_LSTM = y_test_LSTM[-100:,:,:] # initial condition for LSTM (needed to learn the neurons in the hidden layer)

# Initialize resulting arrays
x_AR1 = torch.zeros((len_simu,3))
x_RNN = torch.zeros((len_simu,3)).to(device)
x_AR1[0,:] = x0_AR1
x_RNN[0,:] = x0_LSTM[-1,:]

# Estimate h and c of the LSTM using several Lorenz times
x_RNN_tmp, h_hat, c_hat = model_RNN.forward(x0_LSTM)

# Loop on the previous prediction
for i in range(len_simu-1):
  x_AR1[i+1,:] = model_AR1.forward(x_AR1[i,:]) ### TO DO ###
  x_RNN[i+1,:], h_hat, c_hat = model_RNN.forward_using_last_hidden_layer(x_RNN[i,:].reshape(1,1,3),h_hat, c_hat)### TO DO ###


# Generate the true run
x_truth = odeint(Lorenz_63, y_test[-1,:], arange(0.01,len_simu*dt,dt), args=(sigma,rho,beta))

# %%
#############
### TO DO ###
#############

# Phase-space representation
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
ax.plot(x_truth[:,0], x_truth[:,1], x_truth[:,2], 'k')
ax.plot(x_AR1.detach().numpy()[:,0], x_AR1.detach().numpy()[:,1], x_AR1.detach().numpy()[:,2], 'g')
x_RNN = x_RNN.cpu()
ax.plot(x_RNN.detach().numpy()[:,0], x_RNN.detach().numpy()[:,1], x_RNN.detach().numpy()[:,2], 'r')
ax.set_xlabel('$x_1$', size=20)
ax.set_ylabel('$x_2$', size=20)
ax.set_zlabel('$x_3$', size=20)

# %% [markdown]
# ![](https://raw.githubusercontent.com/mm0806son/Images/main/202111121753567.jpeg)

# %% [markdown]
# **Response:**
#
# xxx TO DO xxx
#
# The prediction result of AR1 has a large gap with the true value, although the original shape is maintained. That of RNN has a tendency to converge to the true value but the trajectories do not fully match with the intended function and the prediction should be further optimized in order to obtain a closer behaviour to reality.

# %% [markdown]
# **Question 6:**
#
# Propose and implement a new LSTM architecture to increase the quality of the prediction. We suggest to transform the input of the RNN, taking into account more time lags (for instance $t-1$, $t-2$, $t-3$) to explain the Lorenz-63 system at time $t$.

# %%
#############
### TO DO ###
#############
